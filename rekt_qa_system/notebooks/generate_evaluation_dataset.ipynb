# %%
import pandas as pd
from openai import OpenAI
import json
from tqdm.auto import tqdm
from jsoncomment import JsonComment

# %%
df_rekt = pd.read_csv('../datasets/web3isgoinggreat_dataset.csv', index_col=0)

# %%
df_rekt = df_rekt.dropna()

# %%
df_rekt = df_rekt[['Hack' in i for i in df_rekt.tags]]

# %%
df_rekt = df_rekt.reset_index()

# %%
df_rekt = df_rekt.drop(columns=['index'])

# %%
df_rekt['id'] = df_rekt.index

# %%
df_rekt
# Out:
#                                                  title             date  \
# 0    "Peripheral" Aave smart contract hacked for $5...  August 28, 2024
# 1    Brothers charged by SEC for $60 million "crypt...  August 26, 2024
# 2       Users suffer losses after Polygon Discord hack  August 24, 2024
# 3    McDonald's Instagram hacked, hackers claim $70...  August 21, 2024
# 4    Crypto holder loses over $55 million to appare...  August 20, 2024
# ..                                                 ...              ...
# 256    Sentiment protocol hacked for almost $1 million    April 4, 2023
# 257  Over $25 million taken from an MEV bot by mali...    April 3, 2023
# 258  Allbridge cross-chain bridge exploited for aro...    April 1, 2023
# 259  Arbitrum airdrop plagued by downtime, bugs, an...   March 31, 2023
# 260                  $8.9 million stolen from SafeMoon   March 28, 2023
#
#                                                summary               tags   id
# 0    The popular defi lending platform, Aave, suffe...       Hack or scam    0
# 1    Brothers Jonathan and Tanner Adam were charged...  Hack or scam, Law    1
# 2    Some fans of the Polygon blockchain, or those ...       Hack or scam    2
# 3    McDonald's Instagram account, as well as the T...       Hack or scam    3
# 4    Someone holding almost $55.5 million in the DA...       Hack or scam    4
# ..                                                 ...                ...  ...
# 256  The Sentiment liquidity protocol on the Arbitr...       Hack or scam  256
# 257  It's a dog-eat dog-world in the crypto univers...       Hack or scam  257
# 258  The Allbridge cross-chain bridge project was e...  Bug, Hack or scam  258
# 259  A token airdrop from the popular Arbitrum Ethe...  Hack or scam, Hmm  259
# 260  If the pump-and-dump didn't get you, the liqui...       Hack or scam  260
#
# [261 rows x 5 columns]

# %%
documents = df_rekt.to_dict(orient='records')

# %%
client = OpenAI(
    base_url='http://localhost:11434/v1/',
    api_key='ollama',
)

# %%
def generate_questions(doc):
    prompt_template = """
    You emulate a user of our cryptocurrency hacks and exploits assistant application.
    Formulate 5 questions this user might ask based on a provided hack or exploit.
    Make the questions specific to this hack or exploit.
    The question need to be able to be answered using the record, and the questions should
    be complete and not too short. Use as fewer words as possible from the record. DO NOT include the answer in the questions.
    
    The record:
    
    title: {title}
    date: {date}
    summary: {summary}
    tags: {tags}
    
    Provide the output in parsable JSON without using code blocks:

    {{
        "questions": [
            "Question 1",
            "Question 2",
            "Question 3",
            "Question 4",
            "Question 5"
        ]
    }}

    """.strip()
    prompt = prompt_template.format(**doc)

    response = client.chat.completions.create(
        model='mistral',
        messages=[{"role": "user", "content": prompt}]
    )

    json_response = response.choices[0].message.content
    return json_response

# %%
results = {}

# %%
parser = JsonComment()

# %%
for doc in tqdm(documents): 
    doc_id = doc['id']
    #if doc_id in results:
        #continue

    questions_raw = generate_questions(doc)

    try:
        questions = parser.loads(questions_raw)
        results[doc_id] = questions['questions']
    except:
        print(doc)
        print(questions_raw)
# Out:
#  54%|███████████████████████████████████████████▊                                     | 141/261 [08:35<07:54,  3.96s/it]
# {'title': 'Samudai treasury drained', 'date': 'November 10, 2023', 'summary': 'The treasury of the Samudai DAO was apparently drained as an attacker compromised the project\'s multisignature wallets and the wallet belonging to the project\'s founder, Kushagra Agarwal. Altogether, around $1.25\xa0million in ETH was stolen.Agarwal sent a message to the thief shortly afterwards, offering a 10% "bounty" in exchange for the return of the rest of the funds. The attacker didn\'t seem to be interested, and in mid-January began tumbling the assets through the Tornado Cash cryptocurrency mixer.Samudai didn\'t seem to publicly acknowledge the theft, even though they\'ve posted on Twitter a few times since then. The organization had raised $2.5\xa0million in pre-seed capital in June 2022.', 'tags': 'Hack or scam', 'id': 140}
#  {
#         'questions': [
#             "'Who compromised the multisignature wallets and the wallet belonging to Kushagra Agarwal in the Samudai treasury draining incident on November 10, 2023?',
#             'What was the amount of ETH that was stolen from the Samudai DAO treasury?',
#             'Did Kushagra Agarwal attempt to negotiate with the attacker for the return of some or all of the stolen funds?, and if so, what was the proposed bounty?',
#             'Did the attacker use Tornado Cash cryptocurrency mixer following the Samudai treasury drain incident?',
#             "'Has Samudai acknowledged the theft publicly, despite posted activities on Twitter since then?'"
#         ]
#     }
#  63%|███████████████████████████████████████████████████▏                             | 165/261 [10:02<06:08,  3.84s/it]
# {'title': 'Remitano hacked for $2.7\xa0million', 'date': 'September 15, 2023', 'summary': 'Crypto exchange Remitano suffered a hack in which $2.7\xa0million in Tether (USDT), USDC, and Ankr was drained from the exchange\'s hot wallets across three blockchains. Luckily for them, Tether was able to freeze $1.9\xa0million of the stolen funds, substantially reducing the attacker\'s profits.Remitano acknowledged the hack, writing that they had suffered a "data breach from a third-party source". They have claimed that users\' assets will not be affected by the theft.Remitano is a peer-to-peer crypto exchange focused on emerging markets, including Nigeria, Pakistan, Venezuela, and Malaysia.', 'tags': 'Hack or scam', 'id': 164}
#  {
#        "questions": [
#            "On which date did Remitano suffer a $2.7 million hack? (Answer: September 15, 2023)",
#            "Which cryptocurrencies were stolen in the Remitano hack? (Answer: Tether (USDT), USDC, and Ankr)",
#            "How much of the stolen funds from the Remitano hack were frozen by Tether? (Answer: $1.9 million)",
#            "What is the focus market of Remitano as indicated in the record? (Answer: Emerging markets including Nigeria, Pakistan, Venezuela, and Malaysia)",
#            "How did Remitano describe the source of the hack mentioned in the record?" (Answer: A "data breach from a third-party source")
#        ]
#    }
# 100%|█████████████████████████████████████████████████████████████████████████████████| 261/261 [15:54<00:00,  3.66s/it]

# %%
json_str = """

{
       "questions": [
           "On which date did Remitano suffer a $2.7 million hack?",
           "Which cryptocurrencies were stolen in the Remitano hack?",
           "How much of the stolen funds from the Remitano hack were frozen by Tether?",
           "What is the focus market of Remitano as indicated in the record?",
           "How did Remitano describe the source of the hack mentioned in the record?"
       ]
   }
      

"""

# %%
questions = parser.loads(json_str)
results[164] = questions['questions']

# %%
results[164]
# Out:
# ['On which date did Remitano suffer a $2.7 million hack?',
#  'Which cryptocurrencies were stolen in the Remitano hack?',
#  'How much of the stolen funds from the Remitano hack were frozen by Tether?',
#  'What is the focus market of Remitano as indicated in the record?',
#  'How did Remitano describe the source of the hack mentioned in the record?']

# %%
final_results = []

for doc_id, questions in results.items():
    for q in questions:
        final_results.append((doc_id, q))

# %%
final_results
# Out:
# [(0,
#   'Who was the attacker that exploited the smart contract in Aave on August 28, 2024?'),
#  (0,
#   "How did the attacker utilize the arbitrary call error to steal funds from multiple contracts within Aave's ecosystem?"),
#  (0,
#   'What was the total amount of tokens leftover from slippage that were accumulated across several blockchain networks?'),
#  (0,
#   'What is the estimated amount stolen by the exploiter during this hack on Aave?'),
#  (0,
#   "In what sense did Aave representatives describe the hack as a 'raid of the tip jar'?"),
#  (1,
#   'Who were the individuals charged by SEC for a $60 million Ponzi scheme involving GCZ Global and Triten Financial Group?'),
#  (1,
#   'What did the accused brothers claim to offer to investors in their crypto bot business, and what percentage returns did they promise?'),
#  (1,
#   "How were the funds of investors utilized according to the SEC's allegations, and how much of it was actually used to pay other investors?"),
#  (1,
#   'In what ways did the brothers use investor funds outside of paying returns, as per the summary?'),
#  (1,
#   'What is the history of one of the brothers, Jonathan Adam, in terms of criminal convictions related to securities law violations?'),
#  (2,
#   'How can I recognize phishing links or compromised members in a Discord server, specifically for Polygon or similar cryptocurrency projects?'),
#  (2,
#   'What steps should I take to secure my tokens when using a platform like Discord for discussions related to cryptocurrencies like Polygon?'),
#  (2,
#   'Given the recent Polygon Discord hack, how can I prevent losing my cryptocurrency funds in future incidents involving server hacks or token distributions?'),
#  (2,
#   'Are there any red flags that could have alerted users about the suspicious nature of the link shared in the Polygon Discord server before clicking it?'),
#  (2,
#   'What is the recommended course of action for those who suffer losses via a hack or scam, like the affected users in this incident?'),
#  (3,
#   "Who hacked McDonald's Instagram account and the Twitter account of a McDonald's marketing director in August 2024?"),
#  (3,
#   'What was the coin promoted on the compromised accounts that caused significant price fluctuations?'),
#  (3,
#   'How much profit did the attacker make from this hack by selling off their holdings of the promoted coin?'),
#  (3,
#   "Why did the token price spike and plunge after the posts to McDonald's followers?"),
#  (3,
#   "What is the significance of the phrase 'you have just been rug pulled' in the compromised Instagram account bio?"),
#  (4,
#   'What was the total value lost in DAI stablecoins due to this apparent phishing attack?'),
#  (4,
#   'Can you provide more details about the transaction that reassigned ownership of the DAI stash to a phishing address?'),
#  (4,
#   'Approximately how long after the original transfer did the victim attempt to withdraw their tokens, and why was the withdrawal attempt unsuccessful?'),
#  (4,
#   'What happened to the remaining portion of the stolen DAI tokens not exchanged for ETH?'),
#  (4,
#   'Is there any available information regarding the current whereabouts or identity of the attacker?'),
#  (5,
#   "What was the duration of imprisonment handed to Shan Hanes for his involvement in a cryptocurrency embezzlement scheme, particularly the 'pig butchering' scam?"),
#  (5,
#   'Which funds were used by Shan Hanes to invest in the fraudulent cryptocurrency scheme, including amounts and dates of fund transfers from Heartland Tri-State Bank?'),
#  (5,
#   "What were the financial impacts of Hanes' actions on both Heartland Tri-State Bank and Equity investors? How much did equity investors lose as a direct result of this scheme?"),
#  (5,
#   "Who else was involved in the cryptocurrency scheme aside from Shan Hanes, given that he took money from various sources such as a local church, investment club, and daughter's college savings?"),
#  (5,
#   "Why did those running the fraudulent cryptocurrency scheme ask for more money to 'unlock' returns on Hanes' investments — suggesting a tactic common with these types of scams?"),
#  (6,
#   "What cryptocurrency project did Austin 'DNP3' Taylor plead guilty to committing wire fraud against?"),
#  (6,
#   "How much money did Austin 'DNP3' Taylor allegedly steal from the CluCoin project he founded?"),
#  (6,
#   "Why did Austin 'DNP3' Taylor use investor funds for gambling purposes in online casinos?"),
#  (6,
#   "What punishments may Austin 'DNP3' Taylor face as a result of his guilty plea and wire fraud conviction?"),
#  (6,
#   'How are victims of this alleged fraud being notified, according to the information provided in the record?'),
#  (7,
#   "How did the scammer make it to the top of Google search rankings for 'Coinbase'?"),
#  (7,
#   'Why was the man in his 60s convinced that the person he spoke with on the phone was a genuine Coinbase support representative?'),
#  (7,
#   'What safeguards could have prevented this individual from losing $100,000 in bitcoin, ether, and US dollars?'),
#  (7,
#   'Are phishing attacks more prevalent in the cryptocurrency industry or traditional finance (TradFi)?'),
#  (7,
#   'Do crypto platforms have similar reverse transaction capabilities as major banking platforms?'),
#  (8,
#   'What was the approximate amount stolen by North Korean developers from a cryptocurrency project through malicious code?'),
#  (8,
#   'How many developers, according to zachxbt, were involved in this activity and had been found working for at least 25 different cryptocurrency projects?'),
#  (8,
#   'Approximately how much money was these developers able to earn over the past month, as per the information provided?'),
#  (8,
#   'In what time frame did zachxbt trace the payment addresses of the mentioned developers (i.e., within this specific incident or over a longer period)?'),
#  (8,
#   'How were the North Korean developers able to maintain multiple identities while working on different crypto projects, as per the record?'),
#  (9,
#   'What was the nature of the incident that resulted in $12 million being taken from the Ronin bridge and what was taken exactly?'),
#  (9,
#   'How did the flaw in the update to the bridge code contribute to the incident?'),
#  (9, 'Who were the main beneficiaries of this incident, and why?'),
#  (9,
#   'What safety feature in the code was triggered due to the maximum amount being exceeded during the incident?'),
#  (9,
#   'What actions were taken by the Ronin team following the detection of the flaw and before bringing the bridge back online?'),
#  (10, 'What was the nature of the exploit on ConvergenceFi?'),
#  (10,
#   "How did the attacker drain the tokens from ConvergenceFi's staking emissions?"),
#  (10,
#   'Why could the attacker set an arbitrary amount of tokens to return in the ConvergenceFi smart contract?'),
#  (10,
#   'What actions were recommended for users by ConvergenceFi after the hack?'),
#  (10,
#   "Why did ConvergenceFi claim their users' funds were safe despite being hacked?"),
#  (11,
#   'Who was the attacker who hacked MonoSwap DEX and how much money has been laundered so far?'),
#  (11,
#   "How did the attack on MonoSwap occur according to the project team's statement?"),
#  (11,
#   'What actions were taken by MonoSwap following the discovery of the hack, as mentioned in their announcement?'),
#  (11,
#   'Incidents like this have happened recently. Can you provide another example where a victim lost cryptocurrency using a similar method of attack (malicious video chat software)?'),
#  (11,
#   'What is the cryptocurrency mixer used by the MonoSwap attacker for laundering the stolen funds?'),
#  (12,
#   'What platform was the dYdX v3 exchange website temporarily compromised on?'),
#  (12,
#   'Was the compromise on the dYdX v3 exchange website connected to any similar events in July 2024?'),
#  (12,
#   'Why did the company behind the dYdX v3 exchange announce a potential sale of their software at the time of the compromise?'),
#  (12,
#   'When did the dYdX upgrade from v3 to v4, and how was this upgrade related to the compromise?'),
#  (12,
#   'Is it safe to use the dYdX v3 exchange now, given that it was compromised?'),
#  (13,
#   'What is the total amount stolen in the WazirX hack that occurred on July 18, 2024?'),
#  (13, 'Which wallet of WazirX was compromised in the hack?'),
#  (13, 'Did WazirX pause withdrawals due to this hack?'),
#  (13,
#   'What significant event led to the separation between WazirX and Binance in 2023?'),
#  (13,
#   'Who is suspected to be behind the WazirX hack, based on evidence observed by blockchain analysts?'),
#  (14,
#   ' Who was the attacker in the LI.FI Protocol hack and what is known about their method of exploitation?'),
#  (14,
#   ' What specific smart contracts were affected in the $10 million wallet drain on LI.FI Protocol, and how can I determine if they affect me?'),
#  (14, ' Should I continue using any LI.FI-powered applications at this time?'),
#  (14,
#   ' How do I revoke permission from the affected smart contracts mentioned in the LI.FI Protocol warning?'),
#  (14,
#   ' What should I do to minimize potential losses if I am a user of projects that build on top of the LI.FI protocol?'),
#  (15,
#   'What is the name of the defi lending project that was hacked for $1.4 million?'),
#  (15,
#   'Which method did the attacker use to manipulate the exchange rate in the Minterest hack?'),
#  (15,
#   'Why did the Minterest protocol pause the supply and borrow portions following the hack?'),
#  (15, 'What attempt has Minterest made to retrieve some of the stolen funds?'),
#  (15, 'On which date did the Minterest hack occur?'),
#  (16,
#   'Who was responsible for the hack on Defi platform Dough Finance, and how did they carry it out using a flash loan attack through the Railgun privacy service?'),
#  (16,
#   'What was the value of the crypto assets misappropriated during the Dough Finance hack in USD and ETH?'),
#  (16,
#   'Was the response from Dough Finance to the hack appropriate, given their threat to pursue all criminal, legal, and administrative avenues available if the attacker did not return the stolen funds?'),
#  (16,
#   'Is it common for DeFi platforms to be exploited through flash loan attacks, and what measures can these platforms take to prevent such attacks in the future?'),
#  (16,
#   'What legal actions have Dough Finance taken or plan to take as they pursue the hacker who carried out the $1.8 million hack?'),
#  (17,
#   'What were the affected Defi protocol websites in this incident? (Answers might include Compound Finance)'),
#  (17,
#   'What was the method used to compromise these websites to replace them with wallet drainers?'),
#  (17, "Why was the 'Unstoppable Domains' web3 domain service also impacted?"),
#  (17,
#   'Who do we attribute this attack to, and which company was targeted? (Answer might include Squarespace)'),
#  (17, 'What advice did Bobby Ong give to users amidst this incident?'),
#  (18,
#   'Who is Andreas Szakacs and what role did he play in the OmegaPro cryptocurrency Ponzi scheme?'),
#  (18, 'In what year did the OneCoin crypto Ponzi begin operating?'),
#  (18,
#   'What was the alleged modus operandi of the OmegaPro investors and how were victims enticed to invest more and more until they could not withdraw funds?'),
#  (18,
#   'Approximately how much money has been claimed in losses by victims related to the OmegaPro Ponzi scheme?'),
#  (18,
#   'Who are some of the other people associated with OneCoin that have been arrested, and who remains a subject of interest?'),
#  (19,
#   "What was the cryptocurrency token promoted by the hacker who compromised Doja Cat's Twitter account on July 8, 2024?"),
#  (19,
#   'Which social media platform did the hacked message originated from (Twitter or Instagram)?'),
#  (19,
#   'How much was the market cap of the promoted token after it reached its peak during the hack?, and what was its subsequent decline?'),
#  (19,
#   "Which other celebrities' Twitter accounts have recently been compromised to promote memecoins besides Doja Cat, as per the information in the record?"),
#  (19, 'What tag is associated with this incident as per the provided record?'),
#  (20, 'Who was affected by the Bittensor wallet drains?'),
#  (20,
#   'Approximately how much TAO tokens and value were siphoned during the hack?'),
#  (20,
#   'What hypothesis was proposed by blockchain sleuth zachxbt regarding the cause of the attack?'),
#  (20,
#   "How did the malicious Bittensor package make it onto Python's PyPi package manager?"),
#  (20, 'What step has Bittensor taken following the attack?'),
#  (21,
#   'What specific wallet was compromised in the Farcana incident and how much FAR was taken?'),
#  (21, 'Did the team confirm the exploitation of their smart contracts?'),
#  (21, 'In what manner was the market maker allegedly compromised?'),
#  (21,
#   "Who are the investors that contributed to Farcana's seed funding round in November 2023?"),
#  (21,
#   'What is the current worth of the FAR still being held by the exploiter?'),
#  (22,
#   'What is the technique used in this incident to defraud the victim from their assets?'),
#  (22,
#   'Which cryptocurrencies were affected in the $11\xa0million loss reported on June 23, 2024?'),
#  (22, 'How does a permit phishing attack work as described in this record?'),
#  (22,
#   'What type of transaction did the scammer make the victim sign to drain assets from their wallets?'),
#  (22, 'Which tags are associated with this incident?'),
#  (23,
#   'Who observed the alleged $3.5 million theft from Sportsbet.io and when was it observed?'),
#  (23,
#   'What cryptocurrencies were affected in the alleged theft at Sportsbet.io?'),
#  (23,
#   'Does SportsBet have confirmed or disclosed any information about the theft yet?'),
#  (23,
#   'Who is suspected to be behind the theft at Sportsbet.io, considering the similarities with a previous hack on BtcTurk?'),
#  (23,
#   'When and against which cryptocurrency exchange was $55 million allegedly stolen?'),
#  (24,
#   'Why did CoinStats promise military-grade encryption if their wallets are affected by a breach?'),
#  (24,
#   "What type of access was requested by CoinStats to track the users' holdings (read/write or read-only)?"),
#  (24,
#   "How were 1,500 user wallets impacted in the CoinStats breach despite their promise of 'ultimate security' for digital assets?"),
#  (24,
#   'What precautions can I take to ensure my wallet is not vulnerable if I am using a similar read-only access application like CoinStats?'),
#  (24,
#   'Despite being marketed as offering read-only access, what could be the possible reasons for nearly $2.2 million worth of losses in the CoinStats breach?'),
#  (25,
#   "Who performed the hack on 50 Cent's accounts to promote the memecoin $GUNIT and how did they make $300,000,000 in 30 minutes?"),
#  (25,
#   'How was the wallet associated with the hack able to make approximately around $722,000 off the token, while the total volume of the token is only $19.8 million?'),
#  (25,
#   'Were any other transactions suspicious or large scale related to 50 Cent promoting the memecoin $GUNIT on his Twitter account and website?'),
#  (25,
#   'What steps were taken by 50 Cent, the memecoin $GUNIT team, or authorities to prevent further such exploitations of social media accounts for crypto promotion or monetary gain?'),
#  (25,
#   "Considering 50 Cent's claim that he has no association with this crypto, can you identify any other associations between 50 Cent and the memecoin $GUNIT that might shed light on the hack?"),
#  (26,
#   'What cryptocurrency exchange was hacked and what were the assets affected?'),
#  (26, 'What was the approximate value of the stolen assets in dollars?'),
#  (26,
#   'Did any other entities freeze any part of the stolen assets? If so, which one(s) and how much?'),
#  (26,
#   'Which cryptocurrencies saw substantial selling that caused significant price movement following the hack?'),
#  (26, 'Who is the newly installed CEO of Binance mentioned in this report?'),
#  (27,
#   'Did CertiK perform the testing of the bug in a manner that exceeded what is considered normal for whitehat security researchers?'),
#  (27,
#   "What was the amount of cryptocurrency taken by CertiK during the supposed 'testing' period and where did they transfer some of this cryptocurrency?"),
#  (27,
#   'Did Kraken allege that CertiK had attempted to extort them? If so, what was the nature of this allegation?'),
#  (27,
#   'What steps did Kraken take in response to the alleged misconduct by CertiK?'),
#  (27,
#   'Is it known if law enforcement is actively investigating the incident between CertiK and Kraken?'),
#  (28,
#   'Who was able to exploit the Holograph tokenization project and mint 1 billion HLG tokens on June 13, 2024?'),
#  (28,
#   'What was the total notional value of the HLG tokens minted in the exploit, and how did this contribution to liquidity affect the token price?'),
#  (28,
#   'In what form (currency) did the attacker cash out approximately $1.2 million from the exploit?'),
#  (28,
#   'Does any involvement with the Holograph protocol by one of the addresses involved in the exploit suggest potential insider knowledge may have been used during the heist?'),
#  (28,
#   'What is the current token price of HLG after the minting of 1 billion additional tokens, representing an 80% drop?'),
#  (29, 'Who is the hacker responsible for both hacks on UwU Lend protocol?'),
#  (29,
#   'What was the total loss incurred by the UwU Lend protocol as a result of these hacks?'),
#  (29,
#   'Has UwU Lend identified and resolved the vulnerability exploited in the first hack, or did it reoccur due to another vulnerability?'),
#  (29,
#   "Is there any pattern or similarity in the vulnerabilities found in projects led by Michael Patryn, also known as '0xSifu'?"),
#  (29,
#   'What is the current status of UwU Lend defi lending protocol following these hacks?'),
#  (30,
#   'How were phishers able to impersonate an Andreessen Horowitz employee using a changed Twitter username?'),
#  (30,
#   "What type of malware was used in connection with the 'Vortax' software and how did it drain cryptocurrency wallets?"),
#  (30,
#   "Why might victims still trust an account even if it differs slightly from the website listing of the associated firm, as was the case with Peter Lauten's account?"),
#  (30,
#   'Who is crypto sleuth zachxbt and how did he first report on this incident involving the draining of $245,000 worth of cryptocurrency?'),
#  (30,
#   'What can be done to mitigate risks or protect against future similar incidents where a phishing scam impersonates a high-ranking employee?'),
#  (31,
#   'Who was the founder of UwU Lend, whose protocol was hacked for around $20 million on June 10, 2024?'),
#  (31,
#   'Can you identify the pseudonym(s) associated with the founder of UwU Lend who was involved in the hacked protocol?'),
#  (31,
#   'What other projects has the founder of UwU Lend been involved with before founding this defi lending protocol?'),
#  (31,
#   'What was the nature of the situation that led to the pause in the UwU Lend protocol following the $20 million hack on June 10, 2024?'),
#  (31,
#   "Is there a connection between the hack of UwU Lend and the individual's past involvement with QuadrigaCX?"),
#  (32,
#   "Who was able to 'recover' assets from Loopring wallets and steal at least $5 million?"),
#  (32,
#   'Why did the attacker succeed in recovering assets from Loopring wallets?'),
#  (32,
#   'How can I protect my assets if I use a single Loopring guardian for account recovery operations?'),
#  (32,
#   'What actions has Loopring taken after their wallet recovery service was breached?'),
#  (32,
#   'Who is Loopring working with to trace the attackers and recover the stolen funds?'),
#  (33,
#   'Who are Cynthia and Eddy Petion, and what were their alleged fraudulent schemes called?'),
#  (33,
#   'How were the victims of the AWS Mining and NovaTech schemes primarily targeted and what were the promises made to them?'),
#  (33,
#   'What was the alleged method by which NovaTech generated returns for investors and how much money deposited actually went into crypto trading?'),
#  (33,
#   'When and where did Cynthia and Eddy Petion move after secretly selling their Florida house, and what comment did Cynthia make to another scheme operator about avoiding arrest?'),
#  (33,
#   'What is the total amount of money deposited into NovaTech from August 2019 to April 2023?'),
#  (34,
#   'How long did it take for the attacker to steal the cryptocurrency after the private key became publicly visible?'),
#  (34,
#   'What was the amount of cryptocurrency the developer lost after his wallet was drained?'),
#  (34,
#   'Why did the blockchain developer lose his cryptocurrency despite the repository being set to private on Github?'),
#  (34,
#   'Which funding grant from which project did the developer apply for that required the private repository to be made public?'),
#  (34,
#   'What is generally bad practice regarding storing sensitive secrets in Github as per the given incident?'),
#  (35,
#   'When did the Lykke crypto exchange suffer an exploit and have over $23.6 million stolen?'),
#  (35,
#   'What was the action taken by Lykke two days after the hack was detected?'),
#  (35,
#   'What were some customer complaints related to their accounts following the exploit?'),
#  (35,
#   'How did outside researchers discover the security breach on the Lykke platform?'),
#  (35,
#   'When and how did Lykke first acknowledged the attack and communicate it to its customers?'),
#  (36,
#   'Who is accused of being involved in a cryptocurrency scam and money laundering operation according to the Justice Department?'),
#  (36,
#   "What was the alleged method used by Widong 'Bill' Guan and others to launder funds through bank accounts?"),
#  (36,
#   'How did the banks become suspicious about the revenue increase for Epoch Times, leading to investigation?'),
#  (36,
#   'What financial gains saw the Epoch Times in comparison to the previous year as a result of this alleged scam?'),
#  (36,
#   "What evidence led the DOJ to investigate the Epoch Times and Widong 'Bill' Guan for their involvement in this operation?"),
#  (37,
#   'What was the method used in the Velocore DEX exploit to drained tokens from the pool?'),
#  (37, 'What role did Tornado Cash play in the Velocore DEX hack?'),
#  (37,
#   'Why did the operators of the Linea layer-2 blockchain choose to halt the chain after the Velocore DEX exploit?'),
#  (37,
#   'How did this incident impact the cryptocurrency ethos, given that it allowed a single operator to unilaterally control a blockchain?'),
#  (37,
#   "What is the goal of Linea's network in terms of decentralization, as stated by its operators after the Velocore DEX exploit?"),
#  (38,
#   'Who was involved in the unauthorized leak of bitcoin from DMM Bitcoin exchange on May 31, 2024?'),
#  (38,
#   'How did the hacker gain access to the company wallet at DMM Bitcoin on May 31, 2024?'),
#  (38,
#   'What specific measures has DMM Bitcoin taken offline while investigating the incident on May 31, 2024?'),
#  (38,
#   'How are they planning to replace the lost funds with help from other companies in their group, as stated by DMM Bitcoin on May 31, 2024?'),
#  (38,
#   'What is the relation of this incident to previous significant cryptocurrency thefts such as the one from Wormhole bridge in February 2022 and FTX in November 2022?'),
#  (39,
#   "Who was accused of hacking the Twitter account of 'Gigantic-Cassocked-Rebirth' and what cryptocurrency were they involved with?"),
#  (39,
#   "What actions did this team take after hacking the influencer's account, specifically regarding their own memecoin and other tokens like ORDI and ETHFI?"),
#  (39,
#   "Approximately how much profit did this team make on the compromised influencer's Twitter account?"),
#  (39,
#   "On what centralized exchanges could the accused party have opened positions that aren't publicly visible?"),
#  (39,
#   'Did the gambit of the accused party seem successful or unsuccessful, given the documented outcomes, and if not, where might they have experienced losses or gains beyond what was reported?'),
#  (40,
#   'Who was responsible for the flash loan attack on Normie memecoin and what was the monetary value they were able to cash out?'),
#  (40,
#   'When was the vulnerability discovered in the Normie memecoin, and why was it never patched?'),
#  (40,
#   'What was the initial market capitalization of Normie memecoin, and what is its current price after the hack?'),
#  (40,
#   'How much did one individual lose due to the flash loan attack on their Normie memecoin holdings?'),
#  (40,
#   'Are there any plans for the return of funds from the attacker or a possible relaunch of the Normie memecoin?'),
#  (41,
#   'Who was the attacker in the Gala Games hack and how were they able to mint $5 billion GALA tokens?'),
#  (41,
#   'In what way did Gala Games attempt to prevent the attacker from swapping more of the stolen tokens?'),
#  (41,
#   'What was the total value that the attacker was able to swap into ETH before their address was frozen?'),
#  (41,
#   'Was the administrator wallet access obtained by a rogue employee or through a compromised admin wallet?'),
#  (41, 'Has Gala Games made a public statement concerning this hack?'),
#  (42, 'Who perpetrated the hack on Pump.fun and how much money was stolen?'),
#  (42,
#   "What were the motivations behind the former employee's actions, as stated in their Twitter post?"),
#  (42,
#   'In what manner did the attacker airdrop the stolen funds to random wallets?'),
#  (42,
#   'What has been the response of Pump.fun to the hack and subsequent theft?, and'),
#  (42,
#   'How has the attacker reacted to statements made by Pump.fun regarding the incident?'),
#  (43, 'What is MEV (Maximal Extractable Value) and how does it work?'),
#  (43,
#   "How did the Peraire-Bueno brothers exploit a flaw in 'MEV-boost' software?"),
#  (43,
#   'What were the bait transactions used by the Peraire-Bueno brothers for and how did they trick MEV bots?'),
#  (43,
#   "What is 'frontrunning' in this context, and how did the brothers execute it?"),
#  (43,
#   'How did the brothers create false signatures to trick the MEV-boost relay into releasing block information?'),
#  (44, 'Who was the apparent whitehat hacker who intervened to recover funds?'),
#  (44,
#   'What assets were successfully stolen by the attacker on the Stack BTC layer-2 chain, and what was their approximate value at the time of theft?'),
#  (44,
#   "Why did the attacker's attempts to steal assets from the project's BNB Chain implementation fail, despite upgrading the contract to a malicious version?"),
#  (44,
#   'What attempts by the exploiter to steal assets on the Ethereum blockchain were unsuccessful, and what was the estimated value of those assets?'),
#  (44,
#   'Who does ALEX Lab believe was responsible for the hack, as stated in their announcement?'),
#  (45,
#   'What is the total amount of funds stolen from Sonne Finance through the hack and exploitation of its smart contracts?'),
#  (45,
#   'Which specific vulnerability in the Sonne Finance smart contracts was exploited for this attack?'),
#  (45,
#   "Why was Sonne Finance's contract paused on the Optimism Ethereum layer-2 chain following the hack?"),
#  (45,
#   'Why does the record mention that Radiant Capital and Rari have also had issues with known vulnerabilities in their code?'),
#  (45,
#   'Why does the record suggest that some of the code used by Sonne Finance is reused from Compound Finance project?'),
#  (46,
#   'What was the identity of the core Cypher contributor who confessed to stealing funds?'),
#  (46,
#   'When and how much money did this Cypher contributor steal from the recovery fund?'),
#  (46,
#   'Why did the contributor confess to the thefts according to his public statement?'),
#  (46,
#   'How much of the recovered funds were actually given back by the contributor to the redemption fund?'),
#  (46,
#   "What was the impact user's response to the theft and redistribution of the recovered funds?"),
#  (47,
#   'How was the exploiter able to create a fake version of the GNUS token on the Fantom blockchain?'),
#  (47,
#   'In what ways were the fake tokens bridged from Fantom to Ethereum and Polygon?'),
#  (47,
#   'How did the exploiter manage to sell the fraudulent tokens as authentic ones?'),
#  (47,
#   "What wasthe mechanism used by the exploiter to drain $1.27 million from GNUS.ai's liquidity pools?"),
#  (47,
#   'Where do unused cycles on various computing devices get utilized in the context of the GNUS.ai project, and what role does cryptocurrency play?'),
#  (48,
#   'Who was the victim in the $72.7 million wallet theft, and what type of Ethereum wallet were they using?'),
#  (48,
#   "What is the tactic known as that takes advantage of crypto traders' tendencies to copy and paste wallet addresses, and how does it function?"),
#  (48,
#   'By creating a new wallet address with identical start and/or ending character strings to addresses used by the victim, and spamming the victim with transactions from that similar address, what consequence did they aim to achieve?'),
#  (48,
#   "What was the agreement between the victim and the exploiter about the stolen funds, and what portion of the total amount did the exploiter retain as a 'bounty'?"),
#  (48,
#   'How did the scammer manage to get the victims to incorrectly copy the spoofed address for future transfers?'),
#  (49,
#   "What was the nature of the vulnerability exploited in the first attack on Pike Finance's smart contracts?"),
#  (49,
#   "Why did the patching attempt by Pike Finance's team introduce new vulnerabilities in their smart contracts during the second attack?"),
#  (49,
#   "In what tokens were the funds stolen during the second attack on Pike Finance's smart contracts?"),
#  (49,
#   'What measures has Pike Finance promised to ensure users are made whole following the exploits?'),
#  (49, 'Who are the key backers of Pike Finance?'),
#  (50,
#   'Who was responsible for the hack on Rain cryptocurrency exchange in April 29, 2024?'),
#  (50,
#   'In what way did the Rain Group cover any potential losses resulting from this incident?'),
#  (50,
#   'What were the suspicious outflows noticed across wallets on multiple blockchains associated with?'),
#  (50,
#   'Were customer funds directly affected by the hack on Rain cryptocurrency exchange?'),
#  (50,
#   "How long after the initial hack was Rain's 'security incident' acknowledged publicly?"),
#  (51, 'What was the nature of the cryptocurrency scam that Jay Mazini ran?'),
#  (51,
#   "What was the total amount of money scammed by Mazini's cryptocurrency scam?"),
#  (51,
#   "Who were the primary victims of Mazini's cryptocurrency scam and where was it based?"),
#  (51, 'How did Jay Mazini use doctored images in his cryptocurrency scam?'),
#  (51,
#   'What other criminal activities was Jay Mazini involved in that contributed to his prison sentence?'),
#  (52,
#   'Who was the target of the flash loan attack on Hedgey Finance that resulted in a loss of approximately $44.7 million?'),
#  (52,
#   'In which blockchain networks did the exploit occur, and what were the respective amounts stolen from each network (Arbitrum layer-2 and Ethereum mainnet)?'),
#  (52,
#   'Did Hedgey Finance confirm the exploit, and if so, how did they respond on-chain?'),
#  (52,
#   'Were any steps provided for the person who performed the exploit to get in touch with Hedgey Finance for discussion, and has there been a response from them yet?'),
#  (52,
#   'What are some potential strategies or security measures that could have prevented this flash loan attack on Hedgey Finance?'),
#  (53,
#   'Who was responsible for the $2 million hack on the Grand Base platform, and what method did they use to compromise the deployer wallet?'),
#  (53,
#   'What were the specific assets (gAssets) that were affected by this hack or rug pull?'),
#  (53,
#   'In total, how many Ethereum (ETH) were taken from the Grand Base project during this incident?'),
#  (53,
#   'Were any steps taken by the Grand Base team to recover the stolen funds or prevent similar incidents in the future?'),
#  (53,
#   'What was the impact of this hack on the value of gAssets and the overall ecosystem of Grand Base?'),
#  (54, 'Who was the target of the recent hack on FixedFloat exchange?'),
#  (54, 'How much was stolen in this latest hack on FixedFloat exchange?'),
#  (54, 'When did this latest hack occur on FixedFloat exchange?'),
#  (54, 'What is the name of the third-party service exploited in this hack?'),
#  (54, 'Who or what is being blamed for the exploitation in this latest hack?'),
#  (55,
#   'Did the Solana ecosystem face a spate of drained wallets between approximately March 2024 and the date this record was written?'),
#  (55,
#   'Were any trading bots identified as potentially involved in the thefts within the Solana ecosystem during that time period?, Specifically, were there connections to the use of Solareum, BonkBot or other trading bots?'),
#  (55,
#   'Did Solareum speculate a possible cause for the wallet draining incidents on their platform?, More specifically, did they suggest that compromised Telegram bot tokens might have allowed attackers to obtain private keys from message history?'),
#  (55,
#   'Has Solareum been accused of any negligence or complicity in the thefts by users?, Specifically, were there criticisms leveled at them for failing to investigate the hack or for being potentially responsible themselves?'),
#  (55,
#   "What was Solareum's response to the accusations on Twitter after their project closure and website deletion?, Did they address the allegations of theft?"),
#  (56,
#   'What was the total amount of assets stolen in the Prisma Finance hack?'),
#  (56,
#   "How did the attacker take advantage of a flaw in Prisma Finance's smart contracts?"),
#  (56,
#   'Why did the first attacker, who stole the bulk of the assets, transfer the funds to Tornado Cash?'),
#  (56,
#   'What were the demands made by the first attacker apart from returning the funds after the hack?'),
#  (56,
#   "How did the attacked party respond to the attacker's criticism and demands for an online press conference?"),
#  (57,
#   'Who are the co-founders of LENX and what roles do they play in the allegations regarding the $10 million rug pull?'),
#  (57,
#   "What was the nature of the massive withdrawals observed from LENX's treasury funds, and where were these funds transferred to?"),
#  (57,
#   'What actions have been taken by the remaining LENX team in response to the stolen funds allegations, specifically towards freezing the receiving account at Binance?'),
#  (57,
#   'In what way is the LENX project connected to Frax Finance lending protocol, and does this connection potentially impact the investigation into the $10 million rug pull allegations?'),
#  (57,
#   'As of the given date (March 26, 2024), have any details been confirmed regarding the alleged movement of funds and the accusations made towards John Kim?'),
#  (58,
#   'Who was the perpetrator behind the $62.5 million hack on the Munchables crypto game?'),
#  (58,
#   'Was the attacker convinced to return the funds, and if so, how did this happen?'),
#  (58,
#   'What evidence supports the claim that the theft was planned since deployment?'),
#  (58,
#   "What are the arguments for and against the proposal of forcibly rolling back the Blast layer-2 blockchain to 'undo' the hack?"),
#  (58,
#   'Why does the Munchables crypto game, according to some, prioritize aspects of gaming over other facets of cryptocurrency ideology?'),
#  (59,
#   'What was the name of the cryptocurrency project that experienced a $16 million exploit?'),
#  (59,
#   'What type of smart contract bug enabled the attacker to mint tokens in this hack?'),
#  (59,
#   'How many CGT governance tokens were minted as a result of this exploit?'),
#  (59,
#   "What was the estimated loss to the project due to the exploit, and why is it different from the token's notional value?"),
#  (59, 'What measures has Curio DAO announced in response to the theft?'),
#  (60,
#   'Why did the ownership of the Lucky Star Currency project get transferred to a malicious smart contract in March 2024?'),
#  (60,
#   'Who was responsible for draining tokens worth approximately $300,000 from holders of the rug-pulled Lucky Star Currency in March 2024?'),
#  (60,
#   'How did the malicious smart contract manage to drain tokens from those who still held them in the Lucky Star Currency project in March 2024?'),
#  (60,
#   'What measures could have been taken to prevent the subsequent rug-pull of the Lucky Star Currency project in March 2024?'),
#  (60,
#   'Is there any ongoing investigation or legal action regarding the second rug-pull of the Lucky Star Currency project in March 2024?'),
#  (61,
#   'What was the name of the blockchain game that was exploited for $4.6 million and on which layer-2 blockchain this occurred?'),
#  (61,
#   'In the exploit of Super Sushi Samurai, how did the attacker take advantage of a vulnerability in its smart contract to drain funds from the project?'),
#  (61,
#   'What action did the attacker take immediately after the theft that led to the return of the stolen funds, and how were they characterized within the project?'),
#  (61,
#   'After returning the funds, what was the subsequent destiny of the $SSS token post exploit, as suggested in the summary?'),
#  (61,
#   'What additional rewards or role did the whitehat hacker receive from the Super Sushi Samurai project team after their intervention?'),
#  (62,
#   'What cryptocurrency was exploited through social engineering in March 2024?'),
#  (62, 'How much Ether and AirDAO tokens were drained in this exploit?'),
#  (62,
#   "What method was used by the attacker to access the AirDAO project's liquidity pool?"),
#  (62, 'Which exchanges were the stolen tokens transferred through?'),
#  (62,
#   'Has any action been taken or announced by AirDAO regarding this exploit?'),
#  (63, 'What was the name of the exploited cryptocurrency exchange?'),
#  (63,
#   'When did the vulnerability in the smart contract that was exploited originate?'),
#  (63,
#   'Which network was used by contemporary users of the exchange prior to the exploit?'),
#  (63,
#   'What type of bug was discovered which allowed the attacker to drain user funds?'),
#  (63, 'How were the stolen funds concealed after the exploit?'),
#  (64, 'Who was responsible for the theft in Wilder World on March 16, 2024?'),
#  (64,
#   'What tokens were stolen from Wilder World and how much was the total value of these tokens?'),
#  (64,
#   'How did the attacker hide the stolen funds? What cryptocurrency tumbler was used?'),
#  (64,
#   "Did Wilder World provide any reason for the contractor's access to the project deployer's private key?"),
#  (64,
#   "Based on the information provided, what evidence suggests that the thief had 'specialized knowledge of ZERO's internal security systems'"),
#  (65, 'Who impersonated the influential crypto trader Ansem on Twitter?'),
#  (65,
#   'How did the impersonator convince people to invest money in a fake Solana memecoin?'),
#  (65,
#   'What was written by the real Ansem in his tweet that might have led some followers into thinking he was launching a new memecoin?'),
#  (65,
#   'What was the total amount of money lost in this scam, and how much did one individual lose specifically?'),
#  (65, 'How were the wallets of the victims drained during the scam?'),
#  (66,
#   "How was the private keys stored in the multi-signature model for Remilia's treasury, according to the report?"),
#  (66,
#   "What assets were stolen during the hack of 'Charlotte Fang', the leader of Remilia project?"),
#  (66,
#   'What is the suspicion surrounding this hack (inside job or external attack)?'),
#  (66,
#   'Were any security safeguards implemented by Remilia after the $1 million loss incident in September 2023? If yes, what were they?'),
#  (66,
#   "What is the mechanism of attack suggested by 'Charlotte Fang' for this incident?"),
#  (67,
#   'How much, if any, funds were taken during the security incident at NFPrompt?'),
#  (67, 'What measures has NFPrompt taken to address this security breach?'),
#  (67,
#   'Are there any specific methods or tools that the hackers used in this attack against NFPrompt?'),
#  (67,
#   'What centralized exchanges have been contacted by NFPrompt to freeze stolen funds?'),
#  (67,
#   'Is the FBI actively investigating the March 15 security incident at NFPrompt?'),
#  (68,
#   'Who perpetrated the exploit on Mozaic Fi and what method did they use to gain access to the private key?'),
#  (68,
#   'Was any action taken against the rogue developer responsible for the attack?'),
#  (68,
#   'What was the significance of a simultaneous large sale of the Mozaic token during the incident?'),
#  (68,
#   'Why were around 90% of the stolen funds moved to the MEXC exchange and how did it help the situation?'),
#  (68,
#   'Is there any potential recovery or mitigation plan for Mozaic Fi in response to this exploit?'),
#  (69,
#   'What was the name of the decentralized lending platform that experienced a hack on March 14, 2024?'),
#  (69,
#   'How did the attacker exploit the MOBOX platform to drain approximately $750,000 in USDT?'),
#  (69,
#   'What specific functions or features within the MOBOX platform were involved in this exploit?'),
#  (69,
#   'Which token was used for the drained funds in the reported hack on the MOBOX platform?'),
#  (69, 'On what date did this exploit happen on the MOBOX lending platform?'),
#  (70, 'Who filed the civil forfeiture action to seize the cryptocurrency?'),
#  (70, 'In which district was the action filed?'),
#  (70, 'What is the approximate total value of the seized cryptocurrency?'),
#  (70, 'Which crypto exchange were the seized funds stored in?'),
#  (70,
#   'How many American victims have been identified, and from how many of these victims were funds transferred?'),
#  (71,
#   'What was the name of the liquid staking protocol that the victim was using?'),
#  (71,
#   "How much Ether (ETH) did the attacker manage to siphon from the victim's wallet?"),
#  (71,
#   'What type of transaction allowed the attacker to siphon funds from the wallet?'),
#  (71,
#   "What was the value (in USD) of the victim's remaining balance in their wallet after the phishing scam?"),
#  (71,
#   "How did the attacker gain access to increase allowance permissions on the victim's ETH wallet?"),
#  (72,
#   'What is the nature of the incident involving Incognito Market (double scam and extortion)?'),
#  (72, 'What was the timeframe in which this incident occurred?'),
#  (72,
#   'Approximately how much money did Incognito Market supposedly exit scam from its users?'),
#  (72,
#   "Did Incognito Market keep their promise to 'auto-encrypt' messages between buyers and sellers, and auto-delete them after an expiry date as claimed?"),
#  (72,
#   'What is the deadline for the threatened release of the stolen data by Incognito Market?'),
#  (73,
#   'What was the total amount of money stolen via Twitter phishing in February 2024?'),
#  (73,
#   'How many victims were there who lost money due to Twitter phishing in February 2024?'),
#  (73,
#   'Who was the victim with the largest individual loss in the February 2024 Twitter phishing incidents?'),
#  (73,
#   'What type of cryptocurrency tokens were drained from the account of the victim with the largest loss in the February 2024 Twitter phishing incidents?'),
#  (73,
#   'What happened to the tokens drained from the account of the victim with the largest loss in the February 2024 Twitter phishing incidents?'),
#  (74,
#   'Who is the suspect alleged to have committed fraudulent acts at Crypto4Winners?'),
#  (74,
#   'What specific information or data suggests that there has been tampering with the assets and historical data of Crypto4Winners with a high degree of sophistication?'),
#  (74,
#   'Why did Crypto4Winners pause withdrawals, and when were they last re-enabled?'),
#  (74,
#   'Has Crypto4Winners officially disclosed the amount that was allegedly stolen in this incident?'),
#  (74,
#   "Despite legal issues in the past, what average returns has Luc Schiltz's company, Crypto4Winners, claimed to have earned since its inception in 2019?"),
#  (75, 'What was the nature of the hack on the Unizen platform?'),
#  (75, 'Which cryptocurrency was affected in the $2.1 million loss?'),
#  (75, 'How did the attacker exploit a vulnerability to initiate the hack?'),
#  (75, "Why did the project team offer a 'bounty' following the hack?"),
#  (75,
#   'What is the status of the remaining funds at the time this information was published?'),
#  (76, 'What type of attack was used in the WOOFi hack on March 5, 2024?'),
#  (76,
#   'How did the attacker manipulate the price of $WOO in the WOOFi DEX implementation on Arbitrum network?'),
#  (76,
#   "Why did the blockchain security firms take fifteen minutes to pause the project's smart contract after detecting the attack?"),
#  (76,
#   'What was the offer made by the WOOFi project team to the attacker who exploited their system?'),
#  (76,
#   'What led the WOOFi project team to believe that they had a strong lead in revealing the identity of the exploiter?'),
#  (77,
#   'Is the hack or scam incident involved here related to The AI Protocol?'),
#  (77, 'What was the value of the tokens stolen in this incident?'),
#  (77,
#   'What technique was used by the attacker for theWallet drainer service phishing?'),
#  (77,
#   'What action was taken in response to this incident within the community governance of The AI Protocol?'),
#  (77,
#   'Did the burning of stolen tokens prevent the attacker from cashing out the funds?'),
#  (78, 'What was the total value of the Shido tokens stolen in this exploit?'),
#  (78, 'How many Shido tokens were stolen as a result of the exploit?'),
#  (78, 'What was the price per token before and after the exploit occurred?'),
#  (78, 'In what form were the stolen tokens converted (e.g., ETH, BTC)?'),
#  (78, 'Has the Shido team issued a bounty for this exploit?'),
#  (79,
#   "Is the issue outlined in the provided report about a bug in Seneca Protocol's smart contract on Ethereum and Arbitrum?"),
#  (79,
#   "What has been stolen from users due to this bug in Seneca Protocol's smart contract as of February 28, 2024?"),
#  (79,
#   'Why is it difficult for the Seneca team to halt the malfunctioning code related to the bug in their smart contract?'),
#  (79,
#   "Is there a way for individual users to protect themselves from these thefts due to the bug in Seneca Protocol's smart contract? If so, how should they do it?"),
#  (79,
#   "Why can't the Seneca team utilize the Pausable module function to stop the thefts, given that their smart contract inherits this module?"),
#  (80, 'What was the nature of the hack on Serenity Shield?'),
#  (80,
#   'Who stole the tokens from the MetaMask wallet belonging to Serenity Shield, and how did they manage to do so?'),
#  (80,
#   'What was the original price and final selling price of the stolen SERSH tokens?'),
#  (80,
#   'Why is a 15% bounty being offered to the hacker in exchange for returning the stolen funds, and why is there no threat of legal action?'),
#  (80,
#   'Are there any links between the Serenity Shield hack and previous incidents such as the exploits at OKX (December 2023) and Concentric (January 2024)? If so, could these vulnerabilities be exploited again in the future?'),
#  (81,
#   "What crypto addresses were used in the scam that compromised Matthew Perry's Twitter account?"),
#  (81, 'In what way did the scammers claim the donations would be used?'),
#  (81,
#   'How did the true Matthew Perry Foundation clarify their involvement and describe the operation as fraudulent?'),
#  (81,
#   "What was the purpose of the Foundation, according to the clarification on Perry's other social media accounts?"),
#  (81,
#   "Why did the Foundation refer to the Twitter posts and crypto addresses shared in them as 'fraudulent'?"),
#  (82, "Who executed the hack on MicroStrategy's Twitter account?"),
#  (82,
#   'What was the purpose of the hack and what action led to the unauthorized access?'),
#  (82,
#   'What wallet or wallets were primarily affected by this hack, and what tokens were drained from them?'),
#  (82,
#   'How did those who fell for the phishing link get redirected to a fake MicroStrategy website?'),
#  (82,
#   'Why was the stolen amount ($440,000) concentrated mainly in one wallet?'),
#  (83,
#   'What was the name of the web3 messaging project that recently launched a token with an error in its link?'),
#  (83,
#   'In what cryptocurrency exchange was the incorrect token linked by the project in question?'),
#  (83,
#   'What type of smart contract did the incorrectly linked token on PancakeSwap represent?'),
#  (83,
# ...
#  (173,
#   "What type of assets can the scammers potentially steal from victims' MetaMask wallets once access is gained?"),
#  (173,
#   'Among the countries mentioned, which one had its Consumer Protection Agency website compromised in this scam?'),
#  (174,
#   'What was the amount stolen from each blockchain in the Stake hack? (ETH, BSC, Polygon)'),
#  (174,
#   'Who is attributing the Stake hack to - private key leak or a sophisticated breach targeting a transaction approval service?'),
#  (174,
#   'Has Stake acknowledged the attack on their Twitter account and provided any information about re-securing the wallets?'),
#  (174,
#   'Which celebrity does Stake have an endorsement deal with and for how much was this deal valued?'),
#  (174,
#   "Who is currently believed to be responsible for the Stake hack based on FBI's announcement?"),
#  (175,
#   "What event led to the loss of life savings for 'Fraternidade Crypto' in August 2023?"),
#  (175,
#   "Which cryptocurrency and corresponding value were stolen from Fraternidade Crypto's wallet?"),
#  (175,
#   "How many NFTs were stolen from Fraternidade Crypto's wallet, and what was their estimated value?"),
#  (175,
#   'What action did Fraternidade Crypto take immediately after realizing his mistake?'),
#  (175,
#   'Did Fraternidade Crypto recover the stolen cryptocurrencies and NFTs, and if so, which ones?'),
#  (176,
#   "What is the vulnerability that led to the draining of $2.1 million from Balancer's DeFi project?"),
#  (176,
#   'Why did Balancer not execute a whitehat attack on their protocol to safeguard the vulnerable funds as suggested by MevRefund?'),
#  (176,
#   'Are there any ongoing mitigation procedures in place to reduce risks related to this vulnerability?'),
#  (176,
#   "How can users prevent further thefts from affected liquidity pools according to Balancer's advice?"),
#  (176,
#   'What steps is Balancer taking to investigate and resolve the issue fully?'),
#  (177,
#   'How did the attacker manage to compromise a Telegram account of a portfolio company founder?'),
#  (177,
#   "What specific contract was set up by the attacker and how did it lead to the draining of SOL Big Brain's wallet?"),
#  (177,
#   'Which tokens were affected in the phishing scam, and what was the approximate value lost for each token?'),
#  (177,
#   'How did the attacker use permit phishing to execute the scam on SOL Big Brain?'),
#  (177,
#   'What actions could have been taken by SOL Big Brain or the crypto community to prevent this loss?'),
#  (178,
#   'Who made the transfer of over 16 trillion $PEPE tokens from the multisig wallet to crypto exchanges?'),
#  (178,
#   'What changes were made to the multisig wallet security requirements, and who authorized these changes?'),
#  (178,
#   "Why did the PEPE team member claim that the transfers were theft by three of the project's other team members on the project's Twitter account?"),
#  (178,
#   'What effect did the allegations of theft or hack have on the $PEPE token price, and what was the percentage change in its value?'),
#  (178,
#   'Is there any evidence supporting or refuting these claims, or any official statement from the $PEPE team regarding this matter?'),
#  (179,
#   'What type of incident occurred where the U.S. Drug Enforcement Administration (DEA) erroneously sent $50,000 to a scammer?'),
#  (179, 'How did the scammer manage to steal the funds from the DEA?'),
#  (179,
#   'What is the name of the tactic the scammer used in this case that often results in success due to the nature of crypto wallet addresses?'),
#  (179,
#   'Why was it challenging for the DEA to recover the stolen funds after the incident?'),
#  (179,
#   'Which law enforcement agency is currently working with the DEA to trace the theft in this case?'),
#  (180,
#   'What was the name of the token involved in the pump-and-dump scheme targeted at law enforcement officers?'),
#  (180,
#   'Approximately how many investors were convinced to pour money into this scheme, and what was the total amount collected?'),
#  (180,
#   "Regarding John DeSalvo's claims about a way for people to take payroll deductions to buy the token, what did he assert would be the guaranteed minimum return on investment?"),
#  (180,
#   'What actions was John DeSalvo accused of taking with the profits from his pump-and-dump scheme, including the purchase and sale of other crypto tokens?'),
#  (180,
#   'Regarding the separate investment scheme John DeSalvo operated through Facebook, what were the allegations made by the SEC about how he handled the gathered investments?'),
#  (181, 'How did the victim lose $900,000 in USDC?'),
#  (181,
#   'What method was used to trick the victim into connecting their crypto wallet on a phishing website?'),
#  (181,
#   "Why was the phishing website able to appear as a legitimate result for 'celer bridge' search?"),
#  (181,
#   'How can I confirm if a Google Ad or search result is genuine when looking for information about cryptocurrency projects?'),
#  (181,
#   'What precautions should be taken to avoid falling victim to such Google Ad phishing attacks in the future?'),
#  (182, 'Who announced the Harbor Protocol exploit on August 19, 2023?'),
#  (182,
#   'What was the initial and current Total Value Locked (TVL) of the project pre-and post-exploit?'),
#  (182, 'What was the peak TVL that the Harbor Project reached previously?'),
#  (182,
#   "How much funds did the exploit drain from the project pools according to Harbor's statement?"),
#  (182, 'What platform can I check the current TVL of the Harbor Protocol?'),
#  (183,
#   'What was the nature of the incident with the Terra website on August 19, 2023? '),
#  (183, 'How did the compromised Terra website affect user wallets?'),
#  (183,
#   "How long were the services on Terra's official website disrupted due to the hijacking?"),
#  (183,
#   'Is it possible to estimate the total amount of funds stolen during the Terra website hijacking incident?'),
#  (183,
#   'Why did the Terra project advise against using their website even after claiming control over the situation?'),
#  (184,
#   'Who were the four firms that audited the Exactly Protocol before the hack?'),
#  (184,
#   'What was the total value locked (TVL) in the Exactly Protocol before and after the hack?'),
#  (184,
#   'How much Ethereum was siphoned from the Exactly Protocol during the attack?'),
#  (184,
#   'Where was the stolen Ether bridged after being siphoned from the Exactly Protocol?'),
#  (184,
#   'What measures has the Exactly Protocol taken to prevent future attacks?'),
#  (185,
#   'Who are the unknown individuals accused of the SIM swap hack on Blockchain Capital co-founder Bart Stephens?'),
#  (185,
#   "Which cryptocurrencies were stolen from Mr. Stephens' hot wallet, and what was the total amount in US dollars?"),
#  (185,
#   "What was the value (in US dollars) of approximately 80 BTC and 6,500 ETH that the attackers attempted to steal from Mr. Stephens' cold wallet?"),
#  (185,
#   'What triggered the email alert that prevented the theft of additional cryptocurrency from the cold wallet belonging to Mr. Stephens?'),
#  (185,
#   'Which specific actions by an as-yet-unknown individual(s) led to the SIM swap hack on Mr. Stephens?'),
#  (186,
#   'Was the RocketSwap hack a result of brute force attack on a server storing private keys?'),
#  (186,
#   'Approximately how much Ether (ETH) was stolen from the RocketSwap project in this hack?'),
#  (186,
#   'Did RocketSwap announce any plans to compensate users affected by the theft? If so, what type of tokens will be airdropped?'),
#  (186,
#   'Is there any recent update on the status of user funds on RocketSwap following the hack?'),
#  (186,
#   'Should projects that have migrated from RocketSwap be concerned about the security of their funds?'),
#  (187,
#   'Which decentralized finance (DeFi) project, Zunami Protocol, was exploited for over $2.1 million?'),
#  (187,
#   "What type of attack was performed on the Zunami Protocol's primary pool, leading to the theft of 1,152 ETH?"),
#  (187,
#   'In what manner were the funds stolen from the Zunami Protocol tumbled to obscure their origin?'),
#  (187,
#   'What was the promised annual percentage yield (APY) that attracted users to the Zunami Protocol prior to the exploit?'),
#  (187,
#   'Which firms, Ackee and HashEx, audited the Zunami Protocol before the exploit?'),
#  (188,
#   "Which cryptocurrency wallets were affected by the 'Milksad' vulnerability disclosed in the Libbitcoin project?"),
#  (188,
#   'What is the specific irresponsible implementation in the Libbitcoin project that led to the production of flawed private keys in multiple wallets?'),
#  (188,
#   'How much estimated loss (in USD) was resultant from exploiting this vulnerability?'),
#  (188,
#   "Can you briefly describe the response of the Libbitcoin team to the disclosure of the 'Milksad' vulnerability by the Distrust security research firm?"),
#  (188,
#   'What is the method used to brute-force the private keys in this attack, and how long does it take on an average gaming PC?'),
#  (189,
#   'What type of scam is targeting web3 job-interested individuals through dedicated portals?'),
#  (189,
#   'Which tokens were stolen from the victim who applied for a beta testing job in a play-to-earn crypto game and received malware instead?'),
#  (189,
#   'What warning did the tweeting user express about not being cautious enough due to the apparent legitimacy of these web3 job listing sites?'),
#  (189,
#   'Why did the scammed user mention their love for Web3, its technology, and people while describing their experience?'),
#  (189,
#   "Which tokens do you think the user had 'various other tokens' from, given it is not explicitly stated in the record?"),
#  (190,
#   'Who was the attacker behind the Cypher protocol exploit in August 7, 2023?'),
#  (190,
#   'Which smart contract of the Cypher protocol was frozen due to the exploit?'),
#  (190,
#   'What cryptocurrencies were stolen during the exploit of the Cypher protocol?'),
#  (190,
#   'Have there been any attempts to negotiate with the attacker for the return of some of the stolen funds? If so, who attempted this and what means did they use?'),
#  (190,
#   'What actions have community members taken in response to the exploit, such as sending NFTs or messages to the attacker?'),
#  (191, 'Why was Steadefi exploited and what were the funds used for?'),
#  (191,
#   'How much money was siphoned from Steadefi in total, and in what cryptocurrency was it denominated?'),
#  (191,
#   'What vulnerability or private key leak allowed the attacker to change the contract owner of Steadefi?'),
#  (191, 'When did this exploit occur according to the provided record?'),
#  (191, 'In which category (Hack or Scam) is it categorized in the record?'),
#  (192, 'What platform was exploited and how much Ether (ETH) was siphoned?'),
#  (192,
#   'Which auditing companies, SolidProof and InterFi, were responsible for the audit of the affected platform before the exploit occurred?'),
#  (192,
#   'What steps was the project planning to take after the exploit, as mentioned in the record?'),
#  (192,
#   "What was the incentive offered by the platform to the exploiter to return the majority of funds siphoned, referred to as a 'bug bounty' in the record?"),
#  (192,
#   'Is this identified issue labeled as a hack or scam, according to the provided tags?'),
#  (193,
#   'Who exploited LeetSwap on Base blockchain and what was the profit made?'),
#  (193,
#   'What function in LeetSwap allowed the attacker to manipulate token prices?'),
#  (193, 'How much of the stolen funds did LeetSwap ask the hacker to return?'),
#  (193,
#   'When was LeetSwap launched on Base blockchain and what is it described as?'),
#  (193,
#   'On which platform (other than Base) has LeetSwap been previously launched?'),
#  (194, 'What is a zero-transfer attack or address poisoning attack?'),
#  (194,
#   'How does a user fall for a zero-transfer attack despite the apparent low likelihood?'),
#  (194,
#   'Why did only 51 minutes elapse between the theft and the assets being frozen by Tether?'),
#  (194,
#   'Who was the victim of this attack that managed to get Tether to intervene so quickly?'),
#  (194,
#   'What steps could users take to avoid falling victim to a similar zero-transfer attack?'),
#  (195,
#   'Which smart contract programming language had an improperly implemented re-entrancy guard, leading to vulnerabilities in some projects?'),
#  (195,
#   "What were the approximate losses suffered by Curve, AlchemixFi, JPEG'd, MetronomeDAO, Ellipsis Finance, and Debridge Finance due to this exploit?"),
#  (195,
#   'Was there any notable whitehat action taken during these exploits, and if so, which projects benefited from such actions?'),
#  (195,
#   "Did the primary exploiter return any of the stolen funds, and if so, in what proportion did they refund AlchemixFi, JPEG'd, and other affected projects?"),
#  (195,
#   'What steps should a project relying on vulnerable versions of the identified smart contract language take to secure their assets?'),
#  (196, 'Who launched the memecoin, Pond0x?'),
#  (196, 'What were the serious flaws discovered in the Pond0x contract?'),
#  (196,
#   "Why did Pauly0x blame traders and suggest it wasn't his fault for the losses?"),
#  (196,
#   'What message did Pauly0x add to the website in relation to the Pond0x incident?'),
#  (196,
#   'Did Pauly0x admit to a hack or scam with regards to the memecoin, Pond0x?'),
#  (197,
#   'Who originally reported the CoinsPaid hack and what evidence did they provide?'),
#  (197,
#   "What was CoinsPaid's initial response to Jameson Lopp's tweet that it 'look[ed] more like a hack'?"),
#  (197,
#   'Who was referred to as possibly being behind the CoinsPaid hack by zachxbt, and why is this group suspected?'),
#  (197,
#   'What was the total amount hacked from CoinsPaid in dollars according to their official announcement?'),
#  (197,
#   'Are there any known connections between Alphapo and CoinsPaid, and if so, what have they been noted for?'),
#  (198,
#   'In which crypto lending platform was an exploit for around $3.4 million found on July 25, 2023?'),
#  (198,
#   'Which vulnerability did the attacker leverage to manipulate token prices and drain funds from EraLend?'),
#  (198,
#   'How did the thief distribute the stolen funds across various wallets and blockchains?'),
#  (198,
#   'What actions has EraLend taken in response to the attack, and who are they collaborating with during their investigation?'),
#  (198,
#   'Has BlockSec issued any warnings regarding potential vulnerabilities for projects that reuse a portion of code from another project (in this case, SyncSwap), and what specific advice have they given?'),
#  (199,
#   'Which cryptocurrency payment processor was hacked for over $60 million?'),
#  (199,
#   "Which gambling platforms are affected by the crypto provider's issue?"),
#  (199,
#   'What specific issue caused HypeDrop to disable withdrawals on their platform?'),
#  (199, 'Which cryptocurrencies were stolen in the Alphapo hot wallet hack?'),
#  (199,
#   'Is it confirmed that normal deposit and withdrawal processes have resumed for affected platforms?'),
#  (200,
#   "What was the amount stolen from Conic Finance's crvUSD pool during the second hack?"),
#  (200,
#   'Which asset pool of Conic Finance was targeted in the second attack, apart from ETH pools?'),
#  (200,
#   "How much did the attacker ultimately profit from the exploit of Conic Finance's crvUSD pool?"),
#  (200,
#   'Were any other asset pools besides ETH and crvUSD affected during the two attacks on Conic Finance?'),
#  (200,
#   "Did Conic Finance's assurance regarding the first hack's limitation to the ETH pool hold true in light of the second attack?"),
#  (201,
#   'What was the amount of ETH stolen in the Conic Finance hack on July 21, 2023?'),
#  (201,
#   'Which smart contract was vulnerable in the Conic Finance DeFi project?'),
#  (201,
#   'What actions did the Conic Finance team take immediately after discovering the exploit?'),
#  (201,
#   'Were there any attempts by Conic Finance to contact the exploiter following the hack?'),
#  (201,
#   'Is the vulnerability that led to the Conic Finance hack known to affect other DeFi projects or smart contracts?'),
#  ...]

# %%
df_results = pd.DataFrame(final_results, columns=['id', 'question'])

# %%
df_results = df_results.sort_values(by='id')

# %%
df_results.to_csv('../datasets/ground-truth-retrieval_web3.csv', index=False)

# %%
df_results['question']
# Out:
# 0       Who was the attacker that exploited the smart ...
# 1       How did the attacker utilize the arbitrary cal...
# 3       What is the estimated amount stolen by the exp...
# 2       What was the total amount of tokens leftover f...
# 4       In what sense did Aave representatives describ...
#                               ...
# 1291    Which code upgrade introduced the bug that fac...
# 1290    How and when was the SafeMoon liquidity pool c...
# 1293    How was the price of the SafeMoon token artifi...
# 1292    What tactic did the attacker use to take advan...
# 1294    What method was used by the attacker to sell t...
# Name: question, Length: 1305, dtype: object
