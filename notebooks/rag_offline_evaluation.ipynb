# %%
import pandas as pd
from tqdm.auto import tqdm
from sentence_transformers import SentenceTransformer
from elasticsearch import Elasticsearch
from openai import OpenAI
from concurrent.futures import ThreadPoolExecutor
import psutil
import json

# %%
v_a = model.encode("Testing 123")
v_b = model.encode("Testing 153")

t = v_a.dot(v_b)

# %%
type(t)
# Out:
# numpy.float32

# %%
df_rekt = pd.read_csv('../datasets/web3isgoinggreat_dataset.csv', index_col=0)
df_rekt = df_rekt.dropna()
df_rekt = df_rekt[['Hack' in i for i  in  df_rekt.tags]]
df_rekt = df_rekt.reset_index()
df_rekt = df_rekt.drop(columns=['index'])
df_rekt['id'] = df_rekt.index

# %%
documents = df_rekt.to_dict(orient='records')
doc_idx = {d['id']: d for d in documents}

# %%
df_gt = pd.read_csv('../datasets/ground-truth-retrieval_web3.csv')

# %%
ground_truth = df_gt.to_dict(orient='records')

# %%
model_name = 'multi-qa-MiniLM-L6-cos-v1'
model = SentenceTransformer(model_name)
# Out:
# /home/seacevedo/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
es_client = Elasticsearch('http://localhost:9200') 

index_settings = {
    "settings": {
        "number_of_shards": 1,
        "number_of_replicas": 0
    },
    "mappings": {
        "properties": {
            "title": {"type": "text"},
            "date": {"type": "text"},
            "summary": {"type": "text"},
            "tags": {"type": "keyword"},
            "id": {"type": "keyword"},
            "title_vec": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            },
            "date_vec": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            },
            "tags_vec": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            },
            "summary_vec": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            },
            "all_vec": {
                "type": "dense_vector",
                "dims": 384,
                "index": True,
                "similarity": "cosine"
            },
        }
    }
}

index_name = "rekt-knowledgebase"
es_client.indices.delete(index=index_name, ignore_unavailable=True)
es_client.indices.create(index=index_name, body=index_settings)
# Out:
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 50
#       3 index_settings = {
#       4     "settings": {
#       5         "number_of_shards": 1,
#    (...)
#      46     }
#      47 }
#      49 index_name = "rekt-knowledgebase"
# ---> 50 es_client.indices.delete(index=index_name, ignore_unavailable=True)
#      51 es_client.indices.create(index=index_name, body=index_settings)
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elasticsearch/_sync/client/utils.py:446, in _rewrite_parameters.<locals>.wrapper.<locals>.wrapped(*args, **kwargs)
#     443         except KeyError:
#     444             pass
# --> 446 return api(*args, **kwargs)
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elasticsearch/_sync/client/indices.py:727, in IndicesClient.delete(self, index, allow_no_indices, error_trace, expand_wildcards, filter_path, human, ignore_unavailable, master_timeout, pretty, timeout)
#     725     __query["timeout"] = timeout
#     726 __headers = {"accept": "application/json"}
# --> 727 return self.perform_request(  # type: ignore[return-value]
#     728     "DELETE",
#     729     __path,
#     730     params=__query,
#     731     headers=__headers,
#     732     endpoint_id="indices.delete",
#     733     path_parts=__path_parts,
#     734 )
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:423, in NamespacedClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     410 def perform_request(
#     411     self,
#     412     method: str,
#    (...)
#     421     # Use the internal clients .perform_request() implementation
#     422     # so we take advantage of their transport options.
# --> 423     return self._client.perform_request(
#     424         method,
#     425         path,
#     426         params=params,
#     427         headers=headers,
#     428         body=body,
#     429         endpoint_id=endpoint_id,
#     430         path_parts=path_parts,
#     431     )
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:271, in BaseClient.perform_request(self, method, path, params, headers, body, endpoint_id, path_parts)
#     255 def perform_request(
#     256     self,
#     257     method: str,
#    (...)
#     264     path_parts: Optional[Mapping[str, Any]] = None,
#     265 ) -> ApiResponse[Any]:
#     266     with self._otel.span(
#     267         method,
#     268         endpoint_id=endpoint_id,
#     269         path_parts=path_parts or {},
#     270     ) as otel_span:
# --> 271         response = self._perform_request(
#     272             method,
#     273             path,
#     274             params=params,
#     275             headers=headers,
#     276             body=body,
#     277             otel_span=otel_span,
#     278         )
#     279         otel_span.set_elastic_cloud_metadata(response.meta.headers)
#     280         return response
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elasticsearch/_sync/client/_base.py:316, in BaseClient._perform_request(self, method, path, params, headers, body, otel_span)
#     313 else:
#     314     target = path
# --> 316 meta, resp_body = self.transport.perform_request(
#     317     method,
#     318     target,
#     319     headers=request_headers,
#     320     body=body,
#     321     request_timeout=self._request_timeout,
#     322     max_retries=self._max_retries,
#     323     retry_on_status=self._retry_on_status,
#     324     retry_on_timeout=self._retry_on_timeout,
#     325     client_meta=self._client_meta,
#     326     otel_span=otel_span,
#     327 )
#     329 # HEAD with a 404 is returned as a normal response
#     330 # since this is used as an 'exists' functionality.
#     331 if not (method == "HEAD" and meta.status == 404) and (
#     332     not 200 <= meta.status < 299
#     333     and (
#    (...)
#     337     )
#     338 ):
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elastic_transport/_transport.py:342, in Transport.perform_request(self, method, target, body, headers, max_retries, retry_on_status, retry_on_timeout, request_timeout, client_meta, otel_span)
#     340 try:
#     341     otel_span.set_node_metadata(node.host, node.port, node.base_url, target)
# --> 342     resp = node.perform_request(
#     343         method,
#     344         target,
#     345         body=request_body,
#     346         headers=request_headers,
#     347         request_timeout=request_timeout,
#     348     )
#     349     _logger.info(
#     350         "%s %s%s [status:%s duration:%.3fs]"
#     351         % (
#    (...)
#     357         )
#     358     )
#     360     if method != "HEAD":
#
# File ~/.local/share/virtualenvs/rekt_qa_system-pBD0ZnT5/lib/python3.10/site-packages/elastic_transport/_node/_http_urllib3.py:202, in Urllib3HttpNode.perform_request(self, method, target, body, headers, request_timeout)
#     194         err = ConnectionError(str(e), errors=(e,))
#     195     self._log_request(
#     196         method=method,
#     197         target=target,
#    (...)
#     200         exception=err,
#     201     )
# --> 202     raise err from None
#     204 meta = ApiResponseMeta(
#     205     node=self.config,
#     206     duration=duration,
#    (...)
#     209     headers=response_headers,
#     210 )
#     211 self._log_request(
#     212     method=method,
#     213     target=target,
#    (...)
#     217     response=data,
#     218 )
#
# ConnectionError: Connection error caused by: ConnectionError(Connection error caused by: NewConnectionError(<urllib3.connection.HTTPConnection object at 0x7ff210230b20>: Failed to establish a new connection: [Errno 111] Connection refused))

# %%
for doc in tqdm(documents):
    title = doc['title']
    summary = doc['summary']
    doc['all_vector'] = model.encode(title + ' ' + summary)
    es_client.index(index=index_name, document=doc)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 261/261 [00:06<00:00, 41.61it/s]

# %%
def elastic_search_hybrid(query): 
    v_q = model.encode(query)
    
    knn_query = {
        "field": "all_vec",
        "query_vector": v_q,
        "k": 5,
        "num_candidates": 10000,
        "boost": 0.8
    }

    keyword_query = {
        "bool": {
            "must": {
                "multi_match": {
                    "query": query,
                    "fields": ["title", "date", "summary", "tags"],
                    "type": "best_fields",
                    "boost": 0.2,
                }
            }
        }
    }

    response = es_client.search(
        index=index_name,
        query=keyword_query,
        knn=knn_query,
        size=5
    )

    result_docs = []

    for hit in response['hits']['hits']:
        result_docs.append(hit['_source'])

    return result_docs

# %%
def question_hybrid(q):
    question = q['question']
    return elastic_search_hybrid(question)

# %%
def build_prompt(query, search_results):

    prompt_template = """
    You're a assistant that informs the user on the latest cryptocurrency hacks and exploits. Answer the QUESTION based on the CONTEXT from our crytocurrency hacks and exploits database.
    Use only the facts from the CONTEXT when answering the QUESTION. Do not include any reference to the CONTEXT in your answer.
    
    QUESTION: {question}
    
    CONTEXT:
    {context}
    """.strip()
    
    entry_template = """
    title: {title}
    date: {date}
    summary: {summary}
    tags: {tags}
    """.strip()
    
    context = ""
    
    for doc in search_results:
        context = context + entry_template.format(**doc) + "\n\n"

    prompt = prompt_template.format(question=query, context=context).strip()
    return prompt

# %%
def llm(prompt, model):
    client = OpenAI(
        base_url='http://localhost:11434/v1/',
        api_key='ollama',
    )
    response = client.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}]
    )
    
    return response.choices[0].message.content

# %%
def map_progress(pool, seq, f):
    results = []

    with tqdm(total=len(seq)) as progress:
        futures = []

        for el in seq:
            future = pool.submit(f, el)
            future.add_done_callback(lambda p: progress.update())
            futures.append(future)

        for future in futures:
            result = future.result()
            results.append(result)

    return results

# %%
def process_record(rec, model="gemma2:2b"):
    answer_llm = rag(rec, model=model)
    
    doc_id = rec['id']
    original_doc = doc_idx[doc_id]
    answer_orig = original_doc['summary']

    return {
        'answer_llm': answer_llm,
        'answer_orig': answer_orig,
        'id': doc_id,
        'question': rec['question'],
    }

# %%
def rag(query, model):
    search_results = question_hybrid(query)
    prompt = build_prompt(query['question'], search_results)
    answer = llm(prompt, model)
    return answer

# %%
pool = ThreadPoolExecutor(max_workers=psutil.cpu_count())
results_gemma = map_progress(pool, ground_truth, process_record)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [22:49<00:00,  1.05s/it]

# %%
json_gemma = json.loads(json.dumps(results_gemma))

# %%
with open('../datasets/results-gemma.json', 'w') as f:
    json.dump(json_gemma, f)

# %%
def process_record(rec, model="phi3"):
    answer_llm = rag(rec, model=model)
    
    doc_id = rec['id']
    original_doc = doc_idx[doc_id]
    answer_orig = original_doc['summary']

    return {
        'answer_llm': answer_llm,
        'answer_orig': answer_orig,
        'id': doc_id,
        'question': rec['question'],
    }

# %%
pool = ThreadPoolExecutor(max_workers=psutil.cpu_count())
results_phi3 = map_progress(pool, ground_truth, process_record)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [56:36<00:00,  2.60s/it]

# %%
json_phi3 = json.loads(json.dumps(results_phi3))

# %%
with open('../datasets/results-phi3.json', 'w') as f:
    json.dump(json_phi3, f)

# %%
def process_record(rec, model="mistral"):
    answer_llm = rag(rec, model=model)
    
    doc_id = rec['id']
    original_doc = doc_idx[doc_id]
    answer_orig = original_doc['summary']

    return {
        'answer_llm': answer_llm,
        'answer_orig': answer_orig,
        'id': doc_id,
        'question': rec['question'],
    }

# %%
pool = ThreadPoolExecutor(max_workers=psutil.cpu_count())
results_mistral = map_progress(pool, ground_truth, process_record)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1305/1305 [1:00:20<00:00,  2.77s/it]

# %%
json_mistral = json.loads(json.dumps(results_mistral))

# %%
with open('../datasets/results-mistral.json', 'w') as f:
    json.dump(json_mistral, f)

# %%
def process_record(rec, model="llama3.1"):
    answer_llm = rag(rec, model=model)
    
    doc_id = rec['id']
    original_doc = doc_idx[doc_id]
    answer_orig = original_doc['summary']

    return {
        'answer_llm': answer_llm,
        'answer_orig': answer_orig,
        'id': doc_id,
        'question': rec['question'],
    }

# %%
pool = ThreadPoolExecutor(max_workers=psutil.cpu_count())
results_llama = map_progress(pool, ground_truth, process_record)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 1305/1305 [3:26:03<00:00,  9.47s/it]

# %%
json_llama = json.loads(json.dumps(results_llama))

# %%
with open('../datasets/results-llama.json', 'w') as f:
    json.dump(json_llama, f)

# %%
def compute_similarity(record):
    answer_orig = record['answer_orig']
    answer_llm = record['answer_llm']
    
    v_llm = model.encode(answer_llm)
    v_orig = model.encode(answer_orig)
    
    return v_llm.dot(v_orig)

# %% [markdown]
# ## Cosine Similarity

# %% [markdown]
# ### Gemma

# %%
df_gemma = pd.read_json('../datasets/results-gemma.json')

# %%
dict_gemma = df_gemma.to_dict(orient='records')

# %%
similarity = []

for record in tqdm(dict_gemma):
   sim = compute_similarity(record)
   similarity.append(sim)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [00:23<00:00, 54.90it/s]

# %%
df_gemma['cosine'] = similarity
df_gemma['cosine'].describe()
# Out:
# count    1305.000000
# mean        0.632725
# std         0.169203
# min         0.061967
# 25%         0.523001
# 50%         0.663565
# 75%         0.762764
# max         0.959846
# Name: cosine, dtype: float64

# %% [markdown]
# ### Phi3

# %%
df_phi3 = pd.read_json('../datasets/results-phi3.json')

# %%
dict_phi3 = df_phi3.to_dict(orient='records')

# %%
similarity = []

for record in tqdm(dict_phi3):
   sim = compute_similarity(record)
   similarity.append(sim)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [00:22<00:00, 58.50it/s]

# %%
df_phi3['cosine'] = similarity
df_phi3['cosine'].describe()
# Out:
# count    1305.000000
# mean        0.054209
# std         0.090633
# min        -0.116379
# 25%        -0.000040
# 50%         0.046980
# 75%         0.086350
# max         0.811990
# Name: cosine, dtype: float64

# %% [markdown]
# ### Mistral

# %%
df_mistral = pd.read_json('../datasets/results-mistral.json')

# %%
dict_mistral = df_mistral.to_dict(orient='records')

# %%
similarity = []

for record in tqdm(dict_mistral):
   sim = compute_similarity(record)
   similarity.append(sim)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [00:22<00:00, 58.22it/s]

# %%
df_mistral['cosine'] = similarity
df_mistral['cosine'].describe()
# Out:
# count    1305.000000
# mean        0.656022
# std         0.148491
# min         0.081942
# 25%         0.566109
# 50%         0.677183
# 75%         0.767298
# max         0.941107
# Name: cosine, dtype: float64

# %% [markdown]
# ### Llama

# %%
df_llama = pd.read_json('../datasets/results-llama.json')

# %%
dict_llama = df_llama.to_dict(orient='records')

# %%
similarity = []

for record in tqdm(dict_llama):
   sim = compute_similarity(record)
   similarity.append(sim)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 1305/1305 [00:33<00:00, 38.97it/s]

# %%
df_llama['cosine'] = similarity
df_llama['cosine'].describe()
# Out:
# count    1305.000000
# mean        0.658443
# std         0.162653
# min         0.006543
# 25%         0.560586
# 50%         0.692744
# 75%         0.779472
# max         0.952975
# Name: cosine, dtype: float64

# %% [markdown]
# ## LLM as a Judge

# %%
judge_prompt_template = """
You are an expert evaluator for a Retrieval-Augmented Generation (RAG) system.
Your task is to analyze the relevance of the generated answer compared to the original answer provided.
Based on the relevance and similarity of the generated answer to the original answer, you will classify
it as "NON_RELEVANT", "PARTLY_RELEVANT", or "RELEVANT".

Here is the data for evaluation:

Original Answer: {answer_orig}
Generated Question: {question}
Generated Answer: {answer_llm}

Please analyze the content and context of the generated answer in relation to the original
answer and provide your evaluation in parsable JSON without using code blocks:

{{
  "Relevance": "NON_RELEVANT" | "PARTLY_RELEVANT" | "RELEVANT",
  "Explanation": "[Provide a brief explanation for your evaluation]"
}}
""".strip()

# %% [markdown]
# ### Gemma

# %%
df_gemma_sample = df_gemma.sample(n=250, random_state=1)

# %%
samples_gemma = df_gemma_sample.to_dict(orient='records')

# %%
evaluations = []

for record in tqdm(samples_gemma):
    prompt = judge_prompt_template.format(**record)
    evaluation = llm(prompt, model='mistral')
    evaluations.append(evaluation)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 250/250 [31:55<00:00,  7.66s/it]

# %%
type(json.loads("""{
  "Relevance": "RELEVANT",
  "Explanation": "The generated answer directly corresponds to a specific detail in the original story about Robb's previous conviction, showing a good understanding of the context and context switching between the different scams. The only aspect where it falls short is by not providing the additional details mentioned in the original answer."
}"""))
# Out:
# dict

# %%
json_evaluations = []

for i, str_eval in enumerate(evaluations):
    try:
        json_eval = json.loads(str_eval)
        json_evaluations.append(json_eval)
    except:
        print(str_eval)
# Out:
# Here is my evaluation as an expert evaluator for the Retrieval-Augmented Generation (RAG) system:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer directly corresponds to a specific detail in the original story about Robb's previous conviction, showing a good understanding of the context and context switching between the different scams. The only aspect where it falls short is by not providing the additional details mentioned in the original answer."
# }
# Here is my analysis in the requested format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially captures the sequence of events, but it deviates from the original answer in specifying how Oulahyane used the victim's credentials. The mention of quick access to crypto assets and sale of NFTs is accurate, but the detail about transferring his own assets before selling victims' is not supported by the original text."
# }
# ```
# Here is the evaluation result in JSON format:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially matches the original answer by mentioning that Loopring is working with law enforcement, which is mentioned as one of their actions in response to the breach. However, it omits crucial information about tracing attackers and recovering stolen funds, making it only partly relevant."
# }
# Here is the analysis of the generated answer's relevance to the original answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions a tactic used by scammers in the cryptocurrency realm, specifically using Google Ad campaigns to impersonate legitimate projects. This is partially relevant to the original answer, which describes an actual incident of phishing through a fake Google Ad for the Celer blockchain bridge. However, the generated answer does not provide any specific details or context about the Celer incident, and instead offers more general advice on verification and caution when searching for cryptocurrency-related information."
# }
# Here is my analysis and classification:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer only mentions the impact of the hack on users' funds, mentioning a specific figure ($624,000), but it lacks any mention or reference to the project's liquidity pool or its total assets (615 ETH) being compromised. Also, it specifically refers to '[the LeetSwap exploit]', which doesn't appear in the original answer, suggesting a possible disconnect with regards to the details."
# }
# Here is my analysis and evaluation of the generated answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially captures the content and context of the original answer, but it simplifies and misses some key details about the incident (e.g. leaked private keys, stolen funds). The statement 'Some observers considered the threat by the unshETH team to be a bluff' is a paraphrased version of the original text, but it does not provide the same level of information or emphasis as the original answer."
# }
# Here is my analysis of the generated answer in relation to the original answer, providing the requested information in JSON format:
#
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer does not address the serious flaws discovered in the Pond0x contract at all. Instead, it essentially says that the source question for the answer does not explicitly mention such flaws and advises seeking further information from other sources. This drastically deviates from the substance of what was asked and the original context provided."
# }
# Here is the analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly mentions that an attacker upgraded the smart contract, used approvals to transfer tokens, and took advantage of them to move assets into their own wallet. However, it lacks the context that the project was abandoned due to financial difficulties, a governance attack was performed by an exploiter targeting users with active smart contract approvals, and the specifics about the asset value or the initial protocol's decentralized nature."
# }
# Here is the analysis of the generated answer compared to the original answer:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately quotes John DeSalvo's promise of a 'guaranteed minimum return on investment' and specifies that it would be '100X'. This directly matches one of the false statements mentioned in the original answer, indicating high relevance."
# }
# Here is the evaluation in JSON format:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer accurately names zachxbt's suspicion, but lacks context and details about the reason behind this suspicion (why zachxbt suspected Lazarus Group). The mention of the connection to the Alphapo hack is not present in the generated answer."
# }
# ```
# Here is the evaluation result:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses a detail mentioned in the original answer (the transfer to the compromised wallet prior to the hack) but lacks the context and significance of that information. Additionally, it incorrectly states the type of assets transferred as Tether stablecoin instead of fiat currency."
# }
# ```
# Here is my analysis:
#
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer does not acknowledge the original loss of $11 million in Aave Ethereum (aEthMK) and Pendle USDe tokens, nor the permit phishing technique used. Instead, it provides a vague statement that the affected cryptocurrency is 'not specified', which is unrelated to the original content and context."
# }
# Here is my evaluation in parsable JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer does not provide the specific Ethereum address but correctly states that it's not listed in the provided context, which shows some understanding of the original answer. However, it doesn't mention the actual exploit or its consequences as mentioned in the original answer."
# }
# ```
#
# In this evaluation:
#
# - **PARTLY_RELEVANT**: The generated answer shows some relevance to the question by acknowledging the lack of address information in the provided text. However, it fails to capture the key details about the exploit itself.
#
# Reasoning for PARTLY_RELEVANT:
#
# *   The generated answer directly responds to the specific question (Which Ethereum address benefited from the Jimbos Protocol exploit?) and admits that this information is "not listed" in the provided context. This partially maintains relevance with the original text, which highlights the exploitation of Jimbos Protocol.
# *   However, it fails to provide essential details surrounding the exploit (e.g., the specifics of how funds were manipulated via a flash loan using slippage for trading pairs) from the original answer.
# Here is the evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially matches the original answer in terms of content and context. The protocol (Rodeo Finance) and the monetary amount (~$884,000) are correct, but it lacks some details present in the original answer, such as the use of Tornado Cash, staking programs, and recovery efforts."
# }
#
# The generated answer is relevant because:
#
# * It correctly identifies the protocol (Rodeo Finance).
# * The monetary amount mentioned ($884,000) is present in the original answer.
# * It implies that a significant breach occurred.
#
# However, it's only partly relevant due to the lack of details from the original context, making it slightly disconnected. A fully relevant response would provide all details about the attack within the explanation
# Here is my analysis and evaluation in the requested format:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the original question, but lacks crucial context. The phrase 'some kind of "shit" in it' from Mark Cuban's quote is accurately captured, however the tone and full implications of his statement are not conveyed."
# }
#
# I classify the generated answer as PARTLY_RELEVANT because it directly quotes a part of Mark Cuban's statement, which is related to the original question. However, the context provided by the rest of the quote (e.g., his comparison of the attacker to someone watching him) is missing and could have significantly clarified the meaning surrounding his phrase "some kind of 'shit' in it".
# Here is the evaluation result in JSON format:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately rephrased and expanded upon the last part of the original answer, specifically mentioning Conic Finance's attempt to contact the exploiter via blockchain message."
# }
# Here is the evaluation result in parsable JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions a 'fake graphic' which is partially relevant to the original answer. However, it does not provide any further details or context about the graphic, unlike the original answer that describes it in more detail."
# }
# ```
#
# In the generated answer, while it's true that a fake graphic was mentioned (which is one of the key points made in the original answer), it didn't delve into the specifics or even acknowledge that it was part of a manipulated SEC Twitter announcement. The generated answer felt too superficial for a proper relevance match to "RELEVANT", yet not completely out-of-place like "NON_RELEVANT". Therefore, I settled on a rating of "PARTLY_RELEVANT" since there is indeed some tangential connection present but the level of detail provided didn't live up fully.
# Here is my evaluation as an expert evaluator for the RAG system:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "$230 million suspicious transfer and compromised multisignature wallet are directly mentioned in the original answer, which this generated answer accurately summarizes. The context of compromise is also properly matched."
# }
# Here is the evaluation result:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly conveys that the attacker manipulated the market and took advantage of flaws in dYdX's risk management, leading to a payout from the insurance fund. However, it omits crucial context about the attack targeting dYdX, which was not mentioned in the original passage."
# }
# ```
#
# I marked this as PARTLY_RELEVANT because the generated answer captures some essential details (manipulation of market, flaws in risk management, and payout) but misses out on critical context that distinguishes it from being fully relevant.
# Here is the analysis in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially covers the information provided in the original answer, but it lacks specificity and context. The generated answer mentions that dYdX upgraded to v4 and sold the software behind their v3 exchange, which is correct, but it doesn't explicitly mention that the v3 website was compromised or the urgency for users not to use it. Furthermore, the generated question's focus on the timing of the upgrade and its relation to the compromise was partially addressed in the response."
# }
# ```
# Here is the analysis of the generated answer's relevance to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies the monetary value of the cash-out, which matches the original answer. However, it incorrectly states that the attacker remained unknown and fails to mention the details about the victim who lost $1.16 million. Additionally, it describes the exploit as 'costly', whereas the original answer specifically mentions a vulnerability in March that was never patched."
# }
# Here's my evaluation in the required format:
#
# ```json
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer is highly relevant to the original answer as it accurately describes the transfer of ownership of the Lucky Star Currency project to a malicious smart contract and the resulting token drain. The only difference is that the generated answer lacks the context about the rug-pull event in October 2023, but this does not detract from its overall relevance."
# }
# ```
# Here is my evaluation:
#
# ```
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer refers to Steadefi, which is not mentioned in the original answer. The amount of Ether siphoned also differs between the two. Furthermore, the context and details provided in the original answer are specific to Uwerx, while the generated answer appears to be unrelated to it."
# }
# ```
#
# I conclude "NON_RELEVANT" because the generated answer is not related to Uwerx or its blockchain-based freelancer marketplace project, as described in the original answer. The answers refer to different projects (Uwerx vs Steadefi) and differ in specific details such as the amount of Ether siphoned.
# Here is the analysis and evaluation of the generated answer compared to the original answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the context, but it lacks specificity. It doesn't reveal which law enforcement agencies Orbit is working with, only confirms that they are collaborating with multiple ones."
# }
# Here is the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially answers the specific question about the attacker's strategy to evade freezing, but it lacks additional context and details found in the original answer. The similarity in phrase structure ('to evade attempts at freezing') is a notable hint of relevance."
# }
# ```
# Here's the evaluation of the generated answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately quotes specific details (Brenda Indah Chunga, aka 'Bitcoin Beautee', securities fraud and offering unregistered securities) from the original answer regarding the charges against her by the SEC. The context also matches as it is related to HyperVerse, which makes the generated answer highly relevant."
# }
# Here is my analysis of the generated answer compared to the original answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly states that a bug in SushiSwap allowed a hacker to steal around 1,800 ETH worth $3.3 million. However, it makes an additional claim about the type of vulnerability (vulnerability injection attack) which is not mentioned or implied in the original text. Furthermore, the context provided is not entirely accurate as the generated answer introduces information not present in the original question."
# }
# Here is the analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "Both the generated answer and original answer mention 'around 40%' of the dYdX insurance fund being drained. However, the generated answer lacks the necessary context provided in the original answer regarding the attack's nature (targeted against dYdX), the manipulated market for Yearn Finance token, and details about how flaws in risk management led to losses that forced the insurance fund payout."
# }
# Here is my evaluation in JSON format:
#
# ```
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer refers to an Ethereum wallet and the transfer of 72.7 million wrapped bitcoin, which deviates significantly from the original context about a Twitter account compromise affecting MicroStrategy and draining $440,000 from a single wallet containing various tokens."
# }
# ```
#
# I classified the relevance as NON_RELEVANT because:
#
# 1. The topic has shifted entirely from discussing the hacking of MicroStrategy's Twitter account to talking about an unrelated Ethereum wallet transaction.
# 2. The scale of the attack mentioned in the generated answer ($72.7 million) is much larger than the $440,000 reported in the original answer
# 3. There is no indication that the original discussion about tokens and wallets was related to Ethereum or Bitcoin wallet transactions.
# 4. The specific details and entities (e.g., wrapped bitcoin, malicious address) mentioned in the generated answer do not align with those found in the original text.
# Here is my evaluation of the generated answer's relevance to the original answer:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately reflects the sentiment and key information from the original answer, specifically highlighting the Foundation's disclaimer labelling the Twitter posts and crypto addresses as 'fraudulent'. The language used in the generated answer is slightly different but effectively conveys the same meaning as the original."
# }
# ```
#
# I classified it as "RELEVANT" because the generated answer successfully captures a specific statement from the original answer, which is the Foundation's response to the scammer's tweets and crypto addresses. Although the wording is not identical, the essential information and sentiment are preserved in the generated answer, making it relevant to the original context.
# Here is the analysis result:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies the total amount ($1.146 million) drained from Levana Protocol's liquidity pool, which matches the original answer. However, it incorrectly estimates the percentage (using 'about') instead of 'around' in the original answer and doesn't mention the unusual duration of the attack, making it only partly relevant to the original content."
# }
# Here is the analysis of the generated answer in relation to the original answer:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer captures one aspect of the debate regarding MEV bots, but it does not fully reflect the context and nuance presented in the original answer. The discussion about the 'sandwich attack' and its details are missing from the generated answer."
# }
# ```
# Here is the analysis of the generated answer in relation to the original answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer accurately reported on the Terra website hijacking, mentioning phishers trying to access users' wallets and the compromised state despite claims of control. However, it only covers a subset of the issues discussed in the original answer (e.g., unclear funds stolen). The tone and content share similarities but don't fully capture the nuances and additional details of the original response."
# }
# Here is my analysis of the generated answer compared to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer is partially relevant because it mentions the correct notional value of the HLG tokens minted in the exploit and the price drop caused by low liquidity. However, it fails to mention the details of the exploit, such as the flaw in the smart contract that allowed the attacker to mint a billion HLG tokens, and also omits the information about the attacker's address being involved with the Holograph protocol."
# }
# Here is the evaluation:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially matches the original answer by mentioning that messages were left in transactions, which is correct. However, it doesn't provide specific information about making allegations or the context of the event, which is relevant to the full understanding of the situation."
# }
# ```
#
# I classified it as PARTLY_RELEVANT because the generated answer has some relation to the original question and contains a true statement (messages were left in transactions), but it lacks critical context and details that would provide a complete understanding of the event.
# Here's my analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer is partially relevant because it accurately quotes BigWhale's claim about having 'ALL OTHER MEANS NECESSARY' at their disposal to address the issue. However, it fails to capture the full context and specificity of BigWhale's statement, particularly regarding their work with assets within the Russian government directly being mentioned later in a separate post on their website. Overall, the generated answer is missing key information that was present in the original answer."
# }
# Here is the evaluation of the generated answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the question, but with significant inaccuracies. It mentions a change to the multisig wallet security requirements, but incorrectly states the reason for this change, attributing it to increased demand and price speculation rather than a malicious act. The generated answer also repeats key points from the original answer (the theft, concerns regarding project security, panic selling resulting in a 17% price drop), but in a manner that distorts their meaning."
# }
# Here is the evaluation result in parsable JSON format:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer accurately captures some key details from the original answer, such as the use of Creole language and promises of 'financial freedom' to lure victims into the pyramid schemes. However, it omits important information about NovaTech using funds from newer investors to pay out supposed returns in a Ponzi fashion. Additionally, the phrase 'freedom from the plantation' is mentioned in the original answer as part of their tactics to target Haitian descent victims, but its meaning and context are not fully conveyed in the generated response."
# }
# Here is my analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer refers to Deltec Bank and the seizure of tens of millions due to a probe into fake crypto investment schemes, which is partially relevant. However, it lacks specific details such as the total amount ($58.5 million), the reasons for the seizure (wire fraud, bank fraud, or money laundering), and the mention of 'shell companies' and 'organized, international criminal money laundering syndicates'. The answer also uses a simplified and less detailed tone compared to the original."
# }
# Here is my evaluation of the generated answer compared to the original answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately quotes from the exact part of the original answer related to the founder's (Scott Purcell) past issue with trade secrets and a lawsuit filed by Banq. Although it doesn't mention any subsequent details about the current status of that specific lawsuit as it originally appeared in the broader context, it's worth noting only this part was specifically asked for."
# }
# Here is the analysis of the generated answer:
#
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer is not even partially relevant to the original question. The correct question based on the context would be 'What additional legal right does the victim seem to grant to the attacker should they accept the offer mentioned in their on-chain message?' and the correct information that can be inferred from this context mentions the specific percentage of stolen funds the victim wants returned, as well as offering not to report the scammer if 50% is given back. However, the generated answer completely ignores this crucial detail and incorrectly states that no additional legal rights are mentioned in the message by the victim."
# }
# Here's my evaluation in the specified format:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately describes how the malicious smart contract drained tokens from those who still held them in the Lucky Star Currency project, which is a key aspect of the original answer. While the exact detail about a reentrancy bug within an old contract is not mentioned in the original answer, it can be inferred as part of the broader context. Therefore, I consider the generated answer to be relevant."
# }
# ```
#
# In my evaluation:
#
# - The generated answer matches one specific action (draining tokens) taken by malicious smart contracts within the Lucky Star Currency project during the specified timeframe.
# - However, the exact detail about a "reentrancy bug" deviates from the provided context of the original answer.
# Therefore, based on the above analysis, I classify this into:
#
#  Relevance = RELEVANT
# Here is the analysis and evaluation of the generated answer relative to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the question by mentioning possible return of funds from the attacker, which is a key point discussed in the original answer. However, it lacks important context such as the magnitude of losses experienced by holders of the token, and does not provide clear information on the likelihood or feasibility of fund return negotiations being successful."
# }
# Here is my evaluation of the generated answer's relevance to the original answer:
#
# ```
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer discusses a completely different exchange (dYdX) and incident than the original answer (BtcTurk hack), with no mention of the specific events, assets, or entities mentioned in the original answer. While it does mention another security incident (Rain) and some related facts about 3Commas, it is not relevant to the question about BtcTurk."
# }
# ```
#
# My reason for classifying this as "NON_RELEVANT" is that the generated answer discusses a different exchange and incident altogether, without providing any information or context related to the original question about BtcTurk. While there are some tangentially related facts mentioned (Rain security incident), they do not address the specific question asked and therefore do not demonstrate relevance to the original answer.
# Here's my analysis:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions that Multichain recommended users to stop using the service and revoke contract approvals, which is correct. However, it also introduces additional information about $107 million in assets being stolen from their blockchain bridge, which is not present in the original answer. This deviates slightly from the context of the original answer, making it PARTLY_RELEVANT rather than RELEVANT."
# }
# Here is my analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer discusses the importance of verifying legitimacy and being cautious with unknown messages, which is somewhat relevant to the context of the phishing scam that SOL Big Brain fell victim to. However, it does not specifically address what actions could have been taken by SOL Big Brain or the crypto community to prevent this loss, but rather provides general advice on preventing future losses. The generated answer does not take into account the specific details and circumstances of the original incident, such as the compromised Telegram account and the use of permit phishing."
# }
# Here is the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer provides some relevant information about the attack and its aftermath, but it oversimplifies the context and doesn't capture the nuances of the original answer. Specifically, the generated answer only mentions that someone sent zero value tokens to a phishing address, whereas the original answer provides more detail on how this occurred (i.e., via an address poisoning attack). Additionally, the generated answer is missing key information about the attack being thwarted and Tether's rapid response."
# }
# ```
#
# The generated answer captures some general details about the attack, but it falls short of providing a comprehensive and accurate summary like the original answer. Hence, I've classified its relevance as "PARTLY_RELEVANT".
# Here is my evaluation:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately identifies Ishan Seenar Sappidee as the inmate who served a twelve-year sentence for running a Ponzi scheme and defrauded Jarryd Hayne of over $500,000 through a bitcoin scam. The context is also correct, referencing the prison setting. However, the precise amount of money involved ($521,000 vs $500,000) is slightly off."
# }
# ```
# Here is the analysis:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partly addresses the question asked, but it does not provide any further information on the implications of the exploit or whether the DAO was able to recover from the attack. The answer correctly states that there is no mention in the provided context about permanent damage, but it fails to expand on this and offer any meaningful analysis."
# }
# ```
#
# In other words, the generated answer is PARTLY_RELEVANT because it acknowledges that there is no information about permanent damage, which matches part of the original answer. However, it fails to provide a more detailed discussion or insights about the DAO's situation after the exploit, making it not fully relevant to the question asked.
# Here is my evaluation of the generated answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the original question, but it also introduces ambiguity. While it correctly acknowledges that the original text does not explicitly mention centralized exchanges and provides some indirect connections, it does not directly answer the question about which exchanges might have such positions. The explanation provided is mostly about what might be inferred from the context rather than a clear answer."
# }
# Here is my analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the question of how outside researchers discovered the security breach on the Lykke platform. However, it mentions that they 'alerted the platform about a potential security breach to its customers', which is slightly different from the original claim that they 'saw suspicious outflows' and notified Lykke. The generated answer also omits other important details from the original answer, such as the theft of $23.6 million and Lykke's subsequent shutdown."
# }
# Here is the evaluation result:
#
#
# {
#    "Relevance": "PARTLY_RELEVANT",
#    "Explanation":
#        The generated answer addresses some aspects of the potential implications related to cascading liquidations, and partially reflects the context of controlled debt repayment as mentioned in the original text. However, it does not cover all relevant points, such as the specific details about the hack, the size of the position, or the exact impact on the market prices, which were present in the original answer.
#  }
# Here is the evaluation:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions Sam Lee, who has indeed been charged in relation to the HyperVerse cryptocurrency investment scheme. However, it does not provide any information about Brenda Indah Chunga or 'Bitcoin Rodney', which are mentioned in the original answer as also being charged. Therefore, while some of the context is similar, the generated answer only partially addresses the information provided in the original answer."
# }
# ```
# Here is the analysis of the generated answer:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer mentions the exploit of a vulnerability in DEI token contracts, which is directly related to the original answer's mention of attackers discovering a vulnerability and exploiting it. However, the specific detail about $7 million being stolen is similar but not the exact match with one in the original (which says 'around $7 million' and later clarifies that '$5.5 million had been returned'). This minor difference in specifics doesn't make the answer completely non-relevant."
# }
# ```
# Here is the analysis of the generated answer's relevance to the original question and answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately provides a list of investors that contributed to Farcana's seed funding round in November 2023, which is in line with the original answer's mention of Farcana raising $10 million from Animoca and Polygon Ventures. However, the generated answer lacks additional context such as the amount raised or any further developments mentioned in the original answer."
# }
# Here is my evaluation of the generated answer:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer touches on some relevant points such as increasing awareness, rigorous due diligence, and ensuring security protocols are robust during development. However, it doesn't directly address the specific incident mentioned in the original answer (phishing scam with fake NFTs) or mention prevention methods that are particular to this type of attack. It's more general advice on crypto-related cybersecurity best practices."
# }
# Here is the evaluation in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions BTC and ETH, but does not convert their values to US dollars as the original answer did. However, it does provide a partial match by mentioning the numbers of BTC and ETH."
# }
# ```
# Here is the evaluation:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer addresses a subset of information from the original answer, specifically mentioning the Blueberry Protocol's plan to repay users and their goal for full repayment. However, it only partially captures the details from the original answer, such as the amount lost, validator payments, and the project's pause due to investigation."
# }
# ```
# Here is the evaluation result in JSON format:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer paraphrases and simplifies the original information about the FinSoul scam, but it only addresses a small aspect of the original content (i.e., how the stolen money was moved). The context is partially correct, as it references Tornado Cash, but the generated answer lacks detail and does not provide any insight into the strategies used by the project team, which is an important part of the original information."
# }
# ```
# {
#
#   "Relevance": "NON_RELEVANT",
#
#   "Explanation": "The generated answer does not pertain to the crypto exchange, which was actually the focus of the original question. The mention of 'Tether stablecoin' introduces an entity unrelated to the context provided in both the original answer and the generated question."
# Here is the evaluation in JSON format:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "Although the generated answer provides some relevant information, it only mentions the approximate value ($8 million) of TAO tokens that were siphoned without specifying the exact number (32,000 TAO). This partial coverage makes me consider the relevance as PARTLY_RELEVANT."
# }
# Here is my evaluation:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies the team behind the Solana-based $CAT memecoin as the ones who hacked the Twitter account of 'Gigantic-Cassocked-Rebirth'. However, it lacks specific details such as the amount of tokens sniped and sold, the results of their positions on ORDI and ETHFI, and the possibility of further actions on centralized exchanges. Additionally, while it mentions market manipulation, this is not explicitly stated in the original answer."
# }
# ```
# Here is my evaluation of the generated answer compared to the original answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately reflects the content and context of the original answer. The key points about Hedgey Finance confirming the exploit and sending a congratulatory message on-chain are correctly included, as well as the lack of an on-chain response from the attacker."
# }
# Here is the evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the context by mentioning that the exact method of gaining access to DMM Bitcoin's wallet 'is not provided in the given context', which is a true statement, but it fails to expand on this point or provide any additional information relevant to the loss of funds discussed in the original answer. The tone and content of the generated answer seem disconnected from the detailed discussion surrounding the significant cryptocurrency theft event."
# }
# Here is the analysis in parsable JSON format:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer is only partially relevant because it answers a specific part of the original article, but misses other important context. The correct answer should have mentioned the $16 million drained, the bug in the smart contract, and the nature of Curio DAO's response to the theft (compensating users over a year-long period). The generated answer correctly includes the last point, but not the others."
# }
# ```
#
# Note: I classified it as PARTLY_RELEVANT because the generated answer only partially addresses the question asked. It's correct that Curio DAO announced compensation, but misses other important details from the original article.
# Here is the analysis in JSON format:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer accurately states that the Aurory team disabled SyncSpace, but only mentions their tweet and omits details about the hack itself, such as the vulnerability being undetected by an audit. The omission of key contextual information from the original answer makes it partially relevant."
# }
# Here is my analysis of the generated answer compared to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mostly mirrors the key detail from the original answer about how the attack on MonoSwap occurred, according to the project team's statement. However, it omits some context and details present in the original response, such as the malicious video chat software being a common crypto-world attack vector and the mention of a previous similar incident."
# }
#
# This evaluation indicates that while the generated answer is partially relevant to the original response, it does not fully capture the nuances and additional information present in the original text.
# Here's the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer is highly similar to the original answer, covering both charges from the US Attorneys and the SEC. It accurately conveys the same information as the original answer."
# }
# ```
# Here is the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "REPEAT_INFO_ONLY",
#   "Explanation": "The generated answer provides the same information as the original text, but in a different format. It does not add any contextual information or insights relevant to the project's security or mechanics, unlike the original answer which discussed the apparent exploit and potential rug pull. However, it still correctly conveys one of the facts mentioned in the original answer."
# }
# ```
#
# Note: I changed "Relevance" from "PARTLY_RELEVANT" to "REPEAT_INFO_ONLY", as the generated answer only repeats a part of the information provided in the original text without adding any new context or insights.
# Here is the evaluation of the generated answer in JSON format:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately reflects a specific detail mentioned in the original article, namely the maximum single wallet loss due to the hack. It matches one of the key statistics reported in the article and does not introduce any new or unrelated information."
# }
# ```
# Here is my analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially addresses the context of the original answer, mentioning 'PlayDapp sent on-chain messages' and 'the offer was ignored'. However, it lacks crucial information provided in the original answer, such as the hack leading to token minting and the subsequent supply inflation. The generated answer might be sufficient for a brief summary or general knowledge question without context, but for an evaluation of the specific event described in the original answer, it is only partially relevant."
# }
# Here is my evaluation:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer 'The specific asset was GMX (over 17,000 units)' directly answers the question and provides the same detail as the original answer regarding the victim's loss. Although it lacks some context from the original answer, the information provided is accurate and relevant to the question."
# }
# Here is my evaluation of the generated answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies some of the highest-value incidents of 'permit phishing' scams between March and April 2023, such as the $4 million loss on March 24. However, it does not provide a comprehensive account of all the incidents mentioned in the original answer, including multiple attacks with significant losses, and instead focuses on specific instances only partially matching the question's requirements."
# }
# Here is my evaluation:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer discusses the non-custodial nature of FixedFloat and its potential benefits in preventing direct losses for users in cases of hacking. It also mentions some caveats, such as potential vulnerabilities to manipulation or other attacks. This is in line with the original answer's discussion of FixedFloat being non-custodial and not impacting user funds directly, but acknowledging some reported issues with frozen transactions and missing funds."
# }
# ```
# Here is my evaluation of the generated answer:
#
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer discusses a different market manipulation incident involving dYdX and Yearn Finance, and does not provide any information about the Farcana blockchain shooting game's compromised wallet or market maker. The content and context are unrelated to the original answer."
# }
# Here is the analysis of the generated answer's relevance and similarity to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer indirectly addresses a related topic, specifically the absence of information on vulnerabilities, whereas the original answer focuses on the specific details of the hack (amount stolen, blockchain used, etc.). Although it doesn't directly provide an answer to the generated question, it implies that no new information was revealed through the recent hacks, which is somewhat related but does not fully address the question about vulnerabilities."
# }
# Here is the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially captures the essence of the scam, specifically mentioning posting fake links. However, it lacks contextual details such as the endorsement by Steve Aoki's name being used to create a token (a phishing campaign), and the involvement of ben.eth retweeting the compromised account, which added to the confusion. The generated answer only mentions the draining of wallets, but not how the scam was carried out beyond posting fake links."
# }
# ```
# Here is the analysis of the generated answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer matches the specific detail about the total loss suffered by Arcadia Finance due to the exploit, which was also mentioned in the original answer. The content and context of the generated answer are directly related to a crucial piece of information from the original answer."
# }
# Here is the evaluation result in parsable JSON format:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer is highly relevant to the original answer as it provides a cumulative loss figure that matches the one mentioned in the original text. The time frame also corresponds almost exactly, with only minor adjustments (October instead of being specified)."
# }
# Here is my analysis and evaluation of the generated answer compared to the original answer:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately quotes the specific method used to defraud Gryphon Digital Mining's CEO (as per the original sentence: 'According to Sphere 3D, Gryphon's CEO was fooled by multiple spoofing attacks...'). The relevant detail from the original answer is maintained in the generated answer while only highlighting this one key aspect."
# }
# Here is my evaluation of the generated answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer provides some accurate information about Jay Mazini's crimes, including cryptocurrency fraud and Ponzi schemes. However, it does not accurately capture the full extent of his other crimes, which are mentioned in the original answer (such as running overlapping schemes and targeting the Muslim community). Additionally, there is a slight exaggeration in the language used to describe his criminal activities (e.g. 'preying on vulnerable individuals and businesses' is not explicitly stated in the original answer), which indicates that the generated answer is an attempt to fill in details rather than directly copying from the original text."
# }
# Here is the analysis:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately conveys that the whitehat hacker received additional rewards (2.5% in SSS tokens and land) and a specific role (tech advisor) from the Super Sushi Samurai project team, which directly corresponds to detailed information provided in the original answer."
# }
# Here is the analysis and evaluation of the generated answer in relation to the original question and answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer provides some relevant information on how to identify phishing links and compromised members on Discord servers, which is related to the original issue described in the Polygon blockchain hack. However, it does not directly address the specific question of recognizing such threats for Polygon or similar cryptocurrency projects. The answer mainly focuses on general best practices for avoiding scams, but does not specifically mention the context of the Polygon Discord hack or the 'pre-migration celebration' token distribution, which was mentioned in the original answer."
# }
# Here's my expert evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer, '0xSifu', is relevant to the original answer because it mentions the pseudonym associated with the founder of UwU Lend. However, it does not address the hacking incident or the context surrounding the protocol's security issues, making it only partly relevant."
# }
# Here is the analysis of the generated answer compared to the original answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer directly addresses the action taken by users, which is mentioned in the original answer as 'suddenly asked users to revoke permissions'. The only difference is in the context (belief of an exploit vs. actual exploit), but the core information is the same. Therefore, it is classified as RELEVANT."
# }
# Here is the analysis of the generated answer's relevance to the original answer:
#
# {
#   "Relevance": "NON_RELEVANT",
# ...
# }
# Here is my analysis:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer provides some relevant information, but it does not directly address the key point made in the original answer regarding the attacker's history and their involvement with previous attacks. The focus on prior reports of address poisoning attacks is partly related to the incidents described in the original answer, as 'at least $5 million from at least 21 victims in the past four months' suggests a pattern of attack, but it does not explicitly state or reinforce this connection, making its relevance limited."
# }
# ```
# Here is the evaluation of the generated answer in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially matches the original answer by mentioning the safety feature, but it lacks context and detail about the maximum amount being exceeded during the incident. The phrase 'triggered due to the maximum amount being exceeded' is accurate, but the rest of the statement is very simplistic compared to the detailed explanation in the original answer."
# }
# ```
#
# I classified it as "PARTLY_RELEVANT" because the generated answer captures a specific detail from the original answer, but does not provide any further context or information about the incident. The tone and wording are also much simpler than the original answer, which suggests that the RAG system was able to distill some relevant information but did not fully capture the nuances of the original response.
# Here is the analysis of the generated answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer mentions zachxbt and their role in exposing the 'Pixel Penguins' NFT fraud, which is consistent with the original answer's account of zachxbt uncovering evidence that the pixel art was stolen from others. However, the generated answer lacks specific details and context about the project and its scope, such as the amount of Ethereum raised by the project (63.5 ETH) or Wang's involvement in promoting it. Nonetheless, the generated answer correctly identifies zachxbt as a key player in exposing the scam, making it partially relevant but with some important contextual omissions."
# }
# Here is my evaluation as parsable JSON:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies frontrunning and its application in the context of MEV bots, but it lacks specifics about the false signatures and tampered block information mentioned in the original answer. Additionally, the language is not identical to that used in the original response."
# }
# ```
#
# Reasoning:
#
# While the generated answer accurately describes the mechanism of frontrunning as employed by Anton and James Peraire-Bueno, it omits some essential details present in the original explanation (e.g., how they managed to trick MEV bots into releasing information about upcoming blocks through 'bait transactions', and their actual profit-making strategies). Therefore, though the core concept of frontrunning is correctly conveyed, the generated answer shows a partial relevance compared to the comprehensive detail provided by the original response. The explanation also notes a difference in expression style, which underscores that while the essence of the process is captured, the original text offers more nuanced descriptions and specific instances not contained within the generated response.
# Here is the analysis in parsable JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly mentions creating fake NFTs and airdropping them to over 500,000 wallets. However, it only partially captures the context and consequences of this action, as it omits the details about the scams landing scammers $1.25 million in assets and the largest single loss exceeding $150,000."
# }
# ```
# Here is my analysis and evaluation of the generated answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer only partially addresses the question 'what does 'zachxbt characterize' in this context...'. It accurately quotes zachxbt's characterization of the tweet, but it goes beyond what is asked and includes additional information about the scam incident. The provided explanation and analysis for the correct evaluation would require further detail to ensure accuracy."
# }
# Here is my evaluation of the generated answer:
#
#  {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer correctly identifies that there was an exploitable function in LeetSwap, although it notes that exact details are not available. This is consistent with the original answer's mention of a hacking incident where an attacker manipulated token prices on August 1 using an unlisted 'function' (emphasis mine). While the generated answer may lack specificity, it does convey that a functional vulnerability existed, which aligns with the overall context provided in the original answer."
# }
# Here is my evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer correctly identifies the co-founder (Jeff Zirlin) and the blockchain game (Axie Infinity), which are key components of the original answer. However, it incorrectly states that the loss was due to a 'hack' on February 22, 2024, whereas the original answer specifies that two crypto wallets were compromised. The date is also not mentioned in the original answer."
# }
# Here is the evaluation of the generated answer in parsable JSON format:
#
# ```json
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions that CertiK is working with the remaining team members to trace the thieves, which is a specific detail mentioned in the original answer. However, it does not provide any additional context or information about the situation, making it less relevant than the original answer."
# }
# ```
#
# My evaluation is `PARTLY_RELEVANT` because the generated answer contains some of the key details from the original answer (i.e., CertiK working with the team to trace thieves), but lacks other important context and information.
# Here is the analysis of the generated answer in relation to the original answer:
#
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer provides similar information about individuals associated with OneCoin, specifically mentioning Karl Sebastian Greenwood and Ruja Ignatova. It does not mention Andreas Szakacs or the OmegaPro Ponzi scheme, but it still addresses the question related to OneCoin."
# }
# Here is the analysis of the generated answer's relevance compared to the original answer, classified in parsable JSON format:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately reports $191 million (and counting) in possible losses related to JPEX exchange, which matches a detail mentioned in the original answer. The context is also relevant as it pertains to complaints filed with police, discussed in the original text."
# }
# ```
#
# This classification reflects that the generated answer effectively retrieves information from the original answer and relays it correctly, making its content highly relevant to the question asked.
# Here is my evaluation:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially captures the information about the flash loan attack on Normie memecoin and one individual's loss, but fails to mention other key details from the original answer, such as the attacker's activities, the token's market cap, or the negotiations for returning funds."
# }
# ```
#
# I judged it as PARTLY_RELEVANT because the generated answer does provide some relevant information about the individual's loss due to the flash loan attack. However, it omits crucial context and other important points mentioned in the original answer, making it only partially relevant.
# Here is my evaluation of the generated answer:
#
# ```
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer accurately summarizes THORSwap's actions to prevent money laundering by an attacker, including pausing their web interface after consultation with advisors, legal counsel, and law enforcement. While some details are omitted (such as the mention of funds being laundered through Railgun and FTX), the core information is present and consistent with the original answer."
# }
# ```
#
# I evaluate it as "RELEVANT" because the generated answer correctly conveys THORSwap's decision to pause their web interface in response to an attacker attempting to launder stolen assets, which matches the main point of the original answer. While there may be some minor omissions and variations in phrasing, the overall content and meaning remain relevant to the context.
# Here is the evaluation result:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer, 'The Cypher contributor stole over $300,000 from the recovery fund', contains specific and direct information related to the original article. Although it doesn't mention the exact time of the theft or provide more context like the original, it accurately restates a key detail about the magnitude of funds involved in the scandal. The generated answer is essentially a concise paraphrase of part of the original content."
# }
# Here is the analysis:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions HypeDrop disabling withdrawals due to issues with their cryptocurrency provider, which is somewhat related to the original answer mentioning Alphapo's hot wallet hack. However, it does not mention the hack or the specific issue caused by 'an issue on the cryptocurrency provider's side', making only some part of the information relevant to the original question."
# }
# Here is my evaluation in JSON format:
#
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer is not entirely accurate as it states that the provided text does not give information about the platforms' social strategy. However, according to the original answer, the platform 'drew in customers by offering financial expertise on social media'. This implies some type of social media strategy was used, making the generated answer partly relevant."
# }
# Here is the analysis result in JSON format:
#
# ```
#  {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "Although the generated answer does not directly mention any specific wallet address associated with the crypto phishing activity, it correctly acknowledges that such information is not present in the original text. However, this response could be considered partly relevant because it addresses the question but does not provide any valuable or specific information regarding the actual wallet address involved in the case."
# }
# ```
# Here's my evaluation of the generated answer in relation to the original answer:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer directly refers to 'investors' who lost funds, which is explicitly mentioned in the original answer. The context and content of the generated answer align with specific details provided in the original answer, making it a relevant response."
# }
# Here is the evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": The generated answer accurately reports the claimed returns of 8–13.5% offered by the accused brothers to investors, as well as their promise that investor funds would be safe. However, it only partially captures the full context and severity of the alleged Ponzi scheme, failing to mention the amount ($53.9 million) used to pay other investors or the specifics about how this money was misused (e.g., building houses, paying off personal expenses).
# Here is my evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer partially matches the content of the original answer. It correctly identifies Fraternidade Crypto's actions after realizing his mistake, but only partially mentions his efforts to relocate the crypto and recover the stolen funds. The missing context is the emotional video he posted and his decision to file a police report, which affects the overall relevance and similarity of the generated answer."
# }
# Here is the evaluation result in JSON format:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": The generated answer partially relates to the original answer. It correctly identifies that the 'permit phishing' scam has existed for over a year, which is consistent with the original answer. However, the specific date of March 11, 2023, being mentioned in the context of Scam Sniffer first detecting instances of the scam is a bit unclear and not explicitly stated in the original answer. The mention of March/April as the investigation period seems relevant to some extent but could be misleading without further context."
# }
# ```
# Here is the evaluation of the generated answer:
#
# ```
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions assets being stolen, but it doesn't specifically mention OpenSeaHackAlert or the context of fake accounts spoofing known crypto research and security alert providers. It seems to reference a different scam with varying asset theft amounts, not directly related to the original scenario described. There is some vagueness in how the numbers were calculated and the exact total stolen amount overall."
# }
# ```
#
# Note that I evaluated it as "PARTLY_RELEVANT" because the generated answer contains concepts like asset theft, but the context and specific details mentioned are not directly relevant or matching the original scenario described.
# Here is the analysis and evaluation:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer mentions that NFPrompt contacted centralized exchanges to freeze stolen funds, which is consistent with the original answer. However, it fails to provide specific details about the names of the exchanges, which is a crucial part of the information present in the original answer."
# }
# Here is my analysis:
#
# {
#   "Relevance": "RELEVANT",
#   "Explanation": "The generated answer 'This information is not available in the provided context' is relevant because it refers to the fact that the original answer does not mention the exact date when the vulnerability was exploited. However, given that one of the original sentences mentions a smart contract deployed in 2019, it can be inferred by the user that this is the date of deployment and possibly also the origin of the vulnerability being exploited. Yet, since the generated question specifically asked about the 'origin' and not 'deployment', its answer remains relevant as it acknowledges the original context does not provide specific information."
# }
# Here's my evaluation in JSON format:
#
# ```
# {
#   "Relevance": "NON_RELEVANT",
#   "Explanation": "The generated answer directly contradicts the relevant information provided in the original answer. The original answer states 'Four individuals who helped launder money...' while the generated answer claims 'The four individuals charged are not named'. This inconsistency makes it clear that the generated answer does not add any new or supplemental information, instead, it contains inaccurately stated details."
# }
# ```
#
# I've classified the relevance of the generated answer as "NON_RELEVANT" because it doesn't provide a correct response to the question and actually introduces conflicting information.
# Here is the analysis of the generated answer's relevance to the original answer:
#
# {
#   "Relevance": "PARTLY_RELEVANT",
#   "Explanation": "The generated answer addresses a specific detail mentioned in the original answer, namely the offer of a 'bounty' and the decision not to pursue legal action. However, it misses the larger context and implications of this decision as described in the original answer. The generated answer tries to provide more information (e.g., offers of 90% return) that is partially relevant, but still doesn't capture the essence of the original answer."
# }

# %%
df_evaluations_gemma = pd.DataFrame(json_evaluations)

# %%
df_evaluations_gemma.Relevance.value_counts(normalize=True)
# Out:
# Relevance
# RELEVANT              0.419913
# PARTLY_RELEVANT       0.393939
# NON_RELEVANT          0.112554
# PARTIALLY_RELEVANT    0.043290
# PARTY_RELEVANT        0.025974
# Partly_Relevant       0.004329
# Name: proportion, dtype: float64

# %% [markdown]
# ### Phi3

# %%
df_phi3_sample = df_phi3.sample(n=250, random_state=1)

# %%
samples_phi3 = df_phi3_sample.to_dict(orient='records')

# %%
evaluations = []

for record in tqdm(samples_phi3):
    prompt = judge_prompt_template.format(**record)
    evaluation = llm(prompt, model='mistral')
    evaluations.append(evaluation)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 250/250 [10:18<00:00,  2.47s/it]

# %%
json_evaluations = []

for i, str_eval in enumerate(evaluations):
    try:
        json_eval = json.loads(str_eval)
        json_evaluations.append(json_eval)
    except:
        print(str_eval)
# Out:
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not provide specific details about the serious flaws discovered in the Pond0x contract. However, it can be deduced from the original answer that the issue revolves around the ability of anyone to transfer coins belonging to other people. The generated answer indirectly refers to this problem by mentioning 'flaws' found in the contract."
#    }
#  {
#       "Relevance": "NON\_RELEVANT",
#       "Explanation": "The generated answer does not directly provide the action taken by BNB Chain within 10 minutes to address the Discord URL hijacking issue."
#    }
#  {
#     "Relevance": "NON\_RELEVANT",
#     "Explanation": "The generated answer does not provide an answer to the provided question 'Who was responsible for the flash loan attack on Normie memecoin and what was the monetary value they were able to cash out?' The text contains unrelated information about a different topic (Dawn of Food Safety Concerns) without any reference or connection to the original answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly identifies the bank (Deltec) that had assets seized by the U.S. Secret Service, but it does not indicate the reasons for the seizure (involvement in probe into fake crypto investment schemes)."
#    }
#  {
#       "Relevance": "PARTIALLY\_RELEVANT",
#       "Explanation": "The generated question and answer are partially relevant because the exploit of the Azuki DAO's smart contract is mentioned in the original text, but the focus of the response should be on whether there was permanent damage after the exploit and the implications. The provided generated answer does not address those specific points."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not specify the exact people charged, but it correctly identifies that someone is involved in the HyperVerse cryptocurrency investment scheme, which aligns with the information provided in the original answer."
#    }
#  {
#        "Relevance": "PARTLY\_RELEVANT",
#        "Explanation": "The generated answer does not directly address the original question, but discusses potential measures that could be taken to prevent similar phishing scams, which were detailed in the original answer. However, no specific suggestions were provided by the original answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer refers to the approximate value that the attackers attempted to steal from Mr. Stephens' cold wallet, and this value is mentioned in the original answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not provide details about how the stolen money was moved through Tornado Cash. However, it is partly relevant as it mentions that the money from the FinSoul scam was tumbled through Tornado Cash, which implies that some information related to movement of funds is involved."
#    }
#  {
#       "Relevance": "NON\_RELEVANT",
#       "Explanation": "The generated answer does not contain any information regarding the amount of TAO tokens and value siphoned during the hack as described in the original answer."
#     }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not directly provide the maximum single wallet loss, but it does contain information that can be used to find the answer (the highest loss from a single wallet was around $657,000). However, the response is incomplete as it doesn't explicitly state the exact monetary value."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not directly provide the monetary value lost during the previous hack of Platypus Finance. However, it references the mention of a hack in the original answer and implies the need for numerical data related to the financial loss from such an incident."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not directly state the specific tool or service used to tumble the funds. However, it is partly relevant because Tornado Cash is mentioned in the original answer as a tool the attacker used to tumble the stolen funds."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does not fully explain how the attacker took advantage of a flaw in Prisma Finance's smart contracts. However, it indirectly acknowledges that an attacker discovered and exploited a vulnerability in the project's smart contracts by stating that they manipulated users' positions and stole some collateral."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer addresses the question by mentioning that October 2022 was not the first security breach to occur at 3Commas. However, it does not provide further details about the previous incident."
#    }
#  {
#       "Relevance": "PARTLY_RELEVANT",
#       "Explanation": "While the generated answer does not directly provide the specific method used by the attacker to gain access to increase allowance permissions, it does imply that the attacker manipulated the Ethereum holder into signing a malicious transaction. The key phrase 'granted the attacker "increase allowance" permissions' is addressed indirectly in the generated answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer only partially answers the question as it reveals that 'fluffypony' or Ricardo Spagni is one of the people who had access to the Monero CCS wallet, but it does not provide the current status of this individual."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer addresses the method by which the scammers airdropped fake NFTs (which is correct), but it does not provide detail on how the scammers managed to do so, nor does it discuss the scale at which this happened - over 500,000 wallets. Though some information is correctly stated, it lacks sufficient depth and context."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer focuses on the returns claimed by Luc Schiltz's company since its inception, which is indeed a part of the original answer. However, it does not directly address the context of the legality or fraudulent activities, despite those issues being mentioned in the original answer."
#    }

# %%
df_evaluations_phi3 = pd.DataFrame(json_evaluations)

# %%
len(df_evaluations_phi3)
# Out:
# 231

# %%
df_evaluations_phi3.Relevance.value_counts(normalize=True)
# Out:
# Relevance
# PARTLY_RELEVANT       0.493506
# NON_RELEVANT          0.372294
# RELEVANT              0.077922
# PARTIALLY_RELEVANT    0.021645
# NONE                  0.008658
# PARTY_RELEVANT        0.008658
# PARTILY_RELEVANT      0.008658
#  PARTLY_RELEVANT      0.004329
# NONE_RELEVANT         0.004329
# Name: proportion, dtype: float64

# %% [markdown]
# ### Mistral

# %%
df_mistral_sample = df_mistral.sample(n=250, random_state=1)

# %%
samples_mistral = df_mistral_sample.to_dict(orient='records')

# %%
evaluations = []

for record in tqdm(samples_mistral):
    prompt = judge_prompt_template.format(**record)
    evaluation = llm(prompt, model='mistral')
    evaluations.append(evaluation)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 250/250 [11:00<00:00,  2.64s/it]

# %%
json_evaluations = []

for i, str_eval in enumerate(evaluations):
    try:
        json_eval = json.loads(str_eval)
        json_evaluations.append(json_eval)
    except:
        print(str_eval)
# Out:
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer mentions that the vulnerability found in Conic Finance is not exclusive to Conic Finance, which is factually correct and part of the original response. However, the generated answer does not accurately address or directly connect the vulnerability described in the original response with any specific example outside of Conic Finance (such as Sonne Finance), nor does it explain how the vulnerability had led to an actual hack in the mentioned case."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly states the reason behind LoveMake's dissatisfaction towards Twitter, which is related to the phishing scam. However, it omits the specific part where LoveMake mentioned Twitter's verification process not helping them notice the fraudulent account because of similarities with the original and verified account. Therefore, while the general idea is correct, the generated answer lacks some crucial details from the original answer."
#    }
#  {
#     "Relevance": "PARTLY\_RELEVANT",
#     "Explanation": "The generated answer indirectly mentions the reason why the Foundation referred to the Twitter posts and crypto addresses as 'fraudulent'. Although it provides a reasonable explanation, it lacks specific details mentioned in the original answer such as the connection between the scammers compromising Matthew Perry's Twitter account and the Foundation not being associated with the fake wallets or the Twitter posts."
#   }
#  {
#     "Relevance": "PARTLY\_RELEVANT",
#     "Explanation": "The generated answer correctly states that the allegation originates from Banq and notes its ongoing status. However, it does not directly address the current status of Fortress Trust in relation to the lawsuit nor other significant details such as the nature of the undisclosed losses associated with Ripple's acquisition"
#   }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer does acknowledge the event of an unauthorized leak at DMM Bitcoin, which is mentioned in the original answer. However, it fails to provide any detail about how the hacker gained access specifically on May 31, 2024. The originalanswer does not contain information regarding this exact date, so it would be impossible for the generated answer to be fully accurate or relevant."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "While the generated answer correctly identifies and mentions the amount of Ethereum drained (126.5 Ether), it does not correctly identify the other token (AirDAO) and its value that was also drained in this exploit."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly identifies that there was a hack on the mentioned protocol (Platypus Finance), but it provides incorrect information about the monetary value of the previous hack. The original answer states 'This is the second apparent hack of Platypus Finance, following an $8.5 million hack'."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer is partially relevant because it correctly mentions the use of a cryptocurrency tumbler (Tornado Cash) to hide stolen funds, which was indeed used in the Wilder World hack. However, the information provided about the Everscale hack is not relevant as this incident is different from the one described in the original answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly mentions that other asset pools were affected by the hack (it is stated in the original answer that 'Although Conic had assured the public that the incident was limited to the ETH pool...'), but it does not specify which other pools may have been affected and only refers to the crvUSD pool which was also mentioned in the original answer. Although a correct interpretation, it is not a full and complete statement of what actually happened."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly identifies that the attacker gained 'increase allowance' permissions through a malicious transaction. However, it doesn't fully convey the sequence of events or the method by which the unsuspecting individual signed the malicious transaction (phishing scam)."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer mentions that the recent hack on Balancer's frontend affected Balancer users, which is partially correct according to the original answer. However, it does not specifically mention that users had their funds stolen or redirected."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "Although the generated answer correctly identifies the exploited crypto lending platform as EraLend, it is not entirely relevant because it mentions a date (July 25, 2023) that does not correspond to the original context. It would be more accurate if the generated answer did not include any specific dates."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer explains why the incident was revealed in May 2023, which aligns with the original answer. However, it incorrectly implies that the announcement of the hack happened in May 2023 when it actually occurred in January 2022."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer discusses various unrelated cases and provides additional information that was not part of the original question or answer. However, it does address one key aspect from the original answer - $53.9 million of investor funds were used to pay other investors in a Ponzi-like manner. Therefore, the relevance is partly met."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer addresses the promise of military-grade encryption made by CoinStats, which is present in the original answer. However, the question asks why the promise was made given that the wallets were affected by a breach. The answer does not directly connect this promise with the incident of the breach. Consequently, it only partially answers the generated question."
#    }

# %%
df_evaluations_mistral = pd.DataFrame(json_evaluations)

# %%
len(df_evaluations_mistral)
# Out:
# 235

# %%
df_evaluations_mistral.Relevance.value_counts(normalize=True)
# Out:
# Relevance
# PARTLY_RELEVANT       0.442553
# RELEVANT              0.425532
# NON_RELEVANT          0.093617
# PARTY_RELEVANT        0.021277
# PARTIALLY_RELEVANT    0.008511
# PARTILY_RELEVANT      0.008511
# Name: proportion, dtype: float64

# %%
0.442553+0.425532
# Out:
# 0.868085

# %%
df_llama_sample = df_llama.sample(n=250, random_state=1)

# %%
samples_llama = df_llama_sample.to_dict(orient='records')

# %%
evaluations = []

for record in tqdm(samples_llama):
    prompt = judge_prompt_template.format(**record)
    evaluation = llm(prompt, model='mistral')
    evaluations.append(evaluation)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████| 250/250 [10:29<00:00,  2.52s/it]

# %%
json_evaluations = []

for i, str_eval in enumerate(evaluations):
    try:
        json_eval = json.loads(str_eval)
        json_evaluations.append(json_eval)
    except:
        print(str_eval)
# Out:
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "Although the generated answer only directly covers part of the original answer (the attempt to contact the exploiter), it indirectly discusses the main topic of 'attempts by Conic Finance to contact the exploiter'. However, it misstates the date of the event, which makes it only partly relevant."
#    }
#  {
#      "Relevance": "PARTIALLY\_RELEVANT",
#      "Explanation": "The generated answer correctly points out that a change was made to the multisig wallet security requirements, specifically reducing the necessary signatures for transactions. However, it misses mentioning the context of how this change occurred so closely before a large transfer of tokens, which raised concerns about the project possibly rug pulling or being hacked."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "While the generated answer correctly identifies that an apparent whitehat hacker intervened to recover funds in regards to the ALEX's XLink bridge incident, it also mistakenly attributes another instance of a potential whitehat intervention to a different incident (Super Sushi Samurai). Therefore, the relevance is marked as 'PARTLY\_RELEVANT'."
#    }
#  {
#     "Relevance": "PARTLY\_RELEVANT",
#     "Explanation": "The generated answer partially correctly explains how the flaw in the update to the bridge code contributed to the incident. However, it does not completely address all aspects of the original answer such as the specific mistakes that caused ETH and USDC worth around $12 million to be taken or the subsequent steps taken by Ronin (e.g., returning the ETH, undergoing an audit before being brought back online)."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer is partially relevant as it correctly identifies the newly installed CEO of Binance, which was mentioned in the original answer. However, the answer lacks context about how the information became relevant to the incident described regarding BtcTurk."
#    }
#  {
#       "Relevance": "PARTIALLY\_RELEVANT",
#       "Explanation": "The generated answer confirms that there was a rug-pull incident in March 2024, which matches the original answer. However, it fails to mention that ownership of the project was transferred to a malicious smart contract and that the investigation or legal action could potentially be related to this malicious entity."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer is partly relevant as it provides accurate information about the consultants (advisors, legal counsel, and law enforcement) involved in THORSwap's decision to pause their web interface. However, additional context about the roles of these consultants or their involvement in making money laundering more challenging for the attacker is missing from the generated answer."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "The generated answer correctly identifies the amount notional value of the tokens siphoned during the attack, which is $4.3 million in this case as per the original answer. However, it does not elaborate on the correct unit (million) used for the notional value, hence making it only partly relevant."
#    }
#  {
#       "Relevance": "PARTLY\_RELEVANT",
#       "Explanation": "In the generated answer, it correctly identifies 'zachxbt' as someone involved in exposing the 'Pixel Penguins' NFT scam. However, it went beyond the provided original answer by mentioning that zachxbt tracked other unrelated fraud cases as well."
#    }
#  {
#       "Relevance": "PARTIALLY\_RELEVANT",
#       "Explanation": "While the generated answer does acknowledge the event of a theft, it fails to provide specific details about the assets stolen and the total amount. However, the original answer provides that specific details: 'According to researcher zachxbt, who himself was one of the impersonated, the scammers have stolen more than $300,000 in various assets using this technique.'"
#    }

# %%
df_evaluations_llama = pd.DataFrame(json_evaluations)

# %%
len(df_evaluations_llama)
# Out:
# 240

# %%
df_evaluations_llama.Relevance.value_counts(normalize=True)
# Out:
# Relevance
# RELEVANT              0.495833
# PARTLY_RELEVANT       0.395833
# NON_RELEVANT          0.079167
# PARTY_RELEVANT        0.012500
# PARTIALLY_RELEVANT    0.008333
# PARTILY_RELEVANT      0.008333
# Name: proportion, dtype: float64

# %%
 0.495833+0.395833
# Out:
# 0.8916660000000001

# %%
import numpy as np

x = np.float32(3.14)
y = x.item() 

print(type(x))
print(type(y))
# Out:
# <class 'numpy.float32'>
# <class 'float'>
